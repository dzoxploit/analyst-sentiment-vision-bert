# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/

# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.0-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.0

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
# Scrape 

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'in.startv.hotstar.dplus',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=1 # defaults to None(means all score)
)

df = pd.DataFrame.from_records(result)
df = df.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])

df.to_csv('disney+-rating-1.tsv', sep='\t', index=False, header=None)

# %%
# Scrape 

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'in.startv.hotstar.dplus',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=2 # defaults to None(means all score)
)

df = pd.DataFrame.from_records(result)
df = df.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])

df.to_csv('disney+-rating-2.tsv', sep='\t', index=False, header=None)

# %%
# Scrape 

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'in.startv.hotstar.dplus',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=3 # defaults to None(means all score)
)

df = pd.DataFrame.from_records(result)
df = df.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])

df.to_csv('disney+-rating-3.tsv', sep='\t', index=False, header=None)

# %%
# Scrape 

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'in.startv.hotstar.dplus',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=4 # defaults to None(means all score)
)

df = pd.DataFrame.from_records(result)
df = df.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])

df.to_csv('disney+-rating-4.tsv', sep='\t', index=False, header=None)

# %%
# Scrape 

from google_play_scraper import Sort, reviews_all

result = reviews_all(
    'in.startv.hotstar.dplus',
    sleep_milliseconds=0, # defaults to 0
    lang='id', # defaults to 'en'
    country='id', # defaults to 'us'
    sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT
    filter_score_with=5 # defaults to None(means all score)
)

df = pd.DataFrame.from_records(result)
df = df.drop(columns=['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt'])

df.to_csv('disney+-rating-5.tsv', sep='\t', index=False, header=None)

# %%
# #Scrape desired number of reviews

# from google_play_scraper import Sort, reviews

# result, continuation_token = reviews(
#     'com.telkom.tracencare',
#     lang='id', # defaults to 'en'
#     country='id', # defaults to 'us'
#     sort=Sort.MOST_RELEVANT, # defaults to Sort.MOST_RELEVANT you can use Sort.NEWEST to get newst reviews
#     count=35000, # defaults to 100
#     filter_score_with=None # defaults to None(means all score) Use 1 or 2 or 3 or 4 or 5 to select certain score
# )

# %%
# df_busu = pd.DataFrame(np.array(result),columns=['review'])

# df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

# df_busu.head()
# Out:
#                                reviewId         userName  \
# 0  3aa3e037-42c9-4091-a22b-f76a032f4eb5    Linda Melanie
# 1  652b7cbb-6994-49c2-8db5-5709d074e339         ShintaNa
# 2  0509018f-81af-44ab-95db-54c06b000d9a     Maykha Pipit
# 3  81e1c495-db6e-4a8a-a3bc-c4e4160cd281  Gisela Nathania
# 4  076738ed-dda3-46eb-8b3b-6de33e85f094   mohammad latip
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...
# 1  https://play-lh.googleusercontent.com/a/AItbvm...
# 2  https://play-lh.googleusercontent.com/a/AItbvm...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a/AItbvm...
#
#                                              content  score  thumbsUpCount  \
# 0  Setelah apk diupdate kok malah saya keluar dar...      1            146
# 1  Kenapa semenjak diperbarui, jadi ngelag, kelua...      2           2244
# 2  Awalnya lancar saja..tapi setelah update tgl 2...      2           1027
# 3  Hmmmm....jd begini. Aku kan udah update ya, te...      4             81
# 4  Aplikasi crash lalu saya uninstall, namun saat...      2             62
#
#   reviewCreatedVersion                  at  \
# 0                4.4.7 2022-07-01 19:46:00
# 1              4.4.3.1 2022-05-14 09:11:18
# 2                4.4.3 2022-05-12 20:02:03
# 3                4.4.8 2022-07-10 11:11:05
# 4                4.4.8 2022-07-06 00:48:13
#
#                                         replyContent           repliedAt
# 0  Halo Linda Melanie,\n\nMohon maaf atas ketidak... 2022-07-02 00:59:42
# 1  Halo,\n\nMohon maaf atas ketidaknyamanan Anda.... 2022-05-14 12:59:30
# 2  Halo Maykha Pipit,\n\nKami mohon maaf atas ket... 2022-05-13 07:28:12
# 3  Halo Ka,\n\nMohon maaf atas ketidaknyamanan An... 2022-07-10 12:11:00
# 4  Halo Mohammad Latip,\nMohon maaf atas ketidakn... 2022-07-06 02:57:25

# %%
# len(df_busu.index) #count the number of data we got
# Out:
# 35000

# %%
# df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#           userName  score                  at  \
# 0    Linda Melanie      1 2022-07-01 19:46:00
# 1         ShintaNa      2 2022-05-14 09:11:18
# 2     Maykha Pipit      2 2022-05-12 20:02:03
# 3  Gisela Nathania      4 2022-07-10 11:11:05
# 4   mohammad latip      2 2022-07-06 00:48:13
#
#                                              content
# 0  Setelah apk diupdate kok malah saya keluar dar...
# 1  Kenapa semenjak diperbarui, jadi ngelag, kelua...
# 2  Awalnya lancar saja..tapi setelah update tgl 2...
# 3  Hmmmm....jd begini. Aku kan udah update ya, te...
# 4  Aplikasi crash lalu saya uninstall, namun saat...

# %%
#Run This Code to Sort the Data By Date 

# new_df = df_busu[['userName', 'score','at', 'content']]
# sorted_df = new_df.sort_values(by='score', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
# sorted_df.head()
# Out:
#               userName  score                  at  \
# 22361       Rizal Ijal      5 2022-05-29 03:23:24
# 25013  Nuning Indriati      5 2022-03-01 10:03:19
# 6691       NOOR ABIDUN      5 2022-07-09 15:08:47
# 25037       Dian Siswa      5 2022-03-08 23:07:13
# 6683      wulan dharma      5 2021-09-01 05:35:50
#
#                                                  content
# 22361                    Baik dan biasa saja apa ada nya
# 25013                        Sangat mudah dan bermanfaat
# 6691                         Aman lancar praktis canggih
# 25037  terimakasih peduli lindubgi atas prokes dan in...
# 6683   okelah skrg dah connect semua, jadi aman buat ...

# %%
# my_df = sorted_df[['userName', 'score','at','content']] #get userName, rating, date-time, and reviews only

# %%
# my_df.head()
# Out:
#               userName  score                  at  \
# 22361       Rizal Ijal      5 2022-05-29 03:23:24
# 25013  Nuning Indriati      5 2022-03-01 10:03:19
# 6691       NOOR ABIDUN      5 2022-07-09 15:08:47
# 25037       Dian Siswa      5 2022-03-08 23:07:13
# 6683      wulan dharma      5 2021-09-01 05:35:50
#
#                                                  content
# 22361                    Baik dan biasa saja apa ada nya
# 25013                        Sangat mudah dan bermanfaat
# 6691                         Aman lancar praktis canggih
# 25037  terimakasih peduli lindubgi atas prokes dan in...
# 6683   okelah skrg dah connect semua, jadi aman buat ...

# %%
# my_df.to_csv("mostrev35k.csv", index = False)  #Save the file as CSV , to download: click the folder icon on the left. the csv file should be there.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Jul 31 05:01:31 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !rm -r indonlu
# Out:
# rm: cannot remove 'indonlu': No such file or directory

# %%
# !git clone https://github.com/ezaaputra/indonlu.git
# !git clone https://github.com/fajri91/InSet.git
# Out:
# Cloning into 'indonlu'...
# remote: Enumerating objects: 460, done.
# remote: Counting objects: 100% (148/148), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 460 (delta 119), reused 108 (delta 108), pack-reused 312
# Receiving objects: 100% (460/460), 4.83 MiB | 16.23 MiB/s, done.
# Resolving deltas: 100% (229/229), done.
# Cloning into 'InSet'...
# remote: Enumerating objects: 16, done.
# remote: Total 16 (delta 0), reused 0 (delta 0), pack-reused 16
# Unpacking objects: 100% (16/16), done.

# %% [markdown]
# # 1. Import Library

# %%
# !pip install emoji
# !pip install Sastrawi
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-2.0.0.tar.gz (197 kB)
#      |████████████████████████████████| 197 kB 5.1 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-2.0.0-py3-none-any.whl size=193022 sha256=946100944500e92f5e5c90962def20f2a6fe9392c380e640587da95980b45485
#   Stored in directory: /root/.cache/pip/wheels/ec/29/4d/3cfe7452ac7d8d83b1930f8a6205c3c9649b24e80f9029fc38
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.0.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 4.1 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.21.0-py3-none-any.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 5.1 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 50.5 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 14.4 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 45.9 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: pyyaml, tokenizers, huggingface-hub, transformers
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed huggingface-hub-0.8.1 pyyaml-6.0 tokenizers-0.12.1 transformers-4.21.0

# %%
import pandas as pd
import numpy as np
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from collections import defaultdict

# NLP
import nltk
nltk.download('punkt')
nltk.download("stopwords")
# from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
import emoji

# Viz
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from wordcloud import WordCloud

#Model IndoBERT
import random
import torch
import torch.nn.functional as F
from torch import optim
from tqdm import tqdm

from transformers import BertForSequenceClassification, BertConfig, BertTokenizer
from indonlu.utils.data_utils import DocumentSentimentDataset, DocumentSentimentDataLoader
from indonlu.utils.forward_fn import forward_sequence_classification
from indonlu.utils.metrics import document_sentiment_metrics_fn
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # 2. Exploratory Data Analysis

# %%
df_path = '/content/drive/MyDrive/asetskripsi/scrlbl6k.txt'
stopword_path = '/content/drive/MyDrive/asetskripsi/stopword2.txt'
kamus_alay_path = '/content/drive/MyDrive/asetskripsi/kamus_alay_syarah.csv'

# %%
# Import data
df = pd.read_csv(df_path, sep='\t', names=['review_text', 'category'])

# %%
df
# Out:
#                                             review_text  category
# 0     #1 Halo kak.. mau ngasi masukan, mungkin bisa ...  negative
# 1     Konten yang sudah di download gak bisa di puta...  negative
# 2     Sorry mau nanya kenapa ya kualitas video sudah...  negative
# 3     Setiap mengganti resolusi ke Tinggi layar tiba...  negative
# 4     Baru instal aplikasi ini, rencananya untuk non...  negative
# ...                                                 ...       ...
# 5995  Gamenya bagus eh maksudnya apk nya hehhehe. Ba...   positif
# 5996  Wanda Vision nya sudah lama gak ada episode ba...   positif
# 5997  Bagus banget apk nya puas pakai dan lagu hemat...   positif
# 5998  Saran aja nih yaa ,, untuk yg gak bisa login d...   positif
# 5999  Terimakasih...Disney dan Telkomsel... good job...   positif
#
# [6000 rows x 2 columns]

# %%
print(f'shape: {df.shape}')
# Out:
# shape: (6000, 2)

# %% [markdown]
# ## Proporsi Variabel Target

# %%
df['category'].value_counts()
# Out:
# negative    2000
# neutral     2000
# positif     2000
# Name: category, dtype: int64

# %%
# Function to make a donut chart
def donut(sizes, ax, angle=90, labels=None,colors=None, explode=None, shadow=None):

    # Plot
    ax.pie(sizes, colors = colors, labels=labels, autopct='%.1f%%', 
           startangle = angle, pctdistance=0.8, explode = explode, 
           wedgeprops=dict(width=0.4), shadow=shadow)

    # Formatting
    plt.axis('equal')  
    plt.tight_layout()

# %%
# Plot arguments
sizes = df.category.value_counts()
labels = ['negative', 'positive', 'neutral']
colors = ['lightgreen', 'lightskyblue', 'lightcoral']
explode = (0,0,0)

# %%
# Create axes
f, ax = plt.subplots(figsize=(6,4))

# plot donut
donut(sizes, ax, 90, labels, colors=colors, explode=explode, shadow=True)
ax.set_title('Review Category Proportions')

plt.show()

# %% [markdown]
# # 3. PreProcessing

# %% [markdown]
# ## Preprocessing Tahap 1

# %%
import pandas as pd 
import numpy as np
df_path = '/content/drive/MyDrive/asetskripsi/scrlbll6k.txt'
Scrapped_Data = pd.read_csv(df_path, sep='\t', names=['review_text', 'category'])

Scrapped_Data.head()
# Out:
#                                          review_text  category
# 0  halo kak  mengasih masuk  timbang atur ukur fo...  positive
# 1  konten download putar   hubungi admin disney  ...  positive
# 2  sorry tanya kualitas video atur mas buram hd  ...  negative
# 3  ganti resolusi layar hitam film mas lanjut  un...  negative
# 4  install aplikasi  rencana menonton series loka...  negative

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
Scrapped_Data['review_text'] = Scrapped_Data['review_text'].str.lower()


print('Case Folding Result : \n')
print(Scrapped_Data['review_text'].head(5))
print('\n\n\n')
# Out:
# Case Folding Result :
#
# 0    halo kak  mengasih masuk  timbang atur ukur fo...
# 1    konten download putar   hubungi admin disney  ...
# 2    sorry tanya kualitas video atur mas buram hd  ...
# 3    ganti resolusi layar hitam film mas lanjut  un...
# 4    install aplikasi  rencana menonton series loka...
# Name: review_text, dtype: object

# %%
import string 
import re #regex library

# import word_tokenize & FreqDist from NLTK
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist

# ------ Tokenizing ---------

def remove_review_text_special(text):
    # remove tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # remove non ASCII (emoticon, chinese word, .etc)
    text = text.encode('ascii', 'replace').decode('ascii')
    # remove mention, link, hashtag
    text = ' '.join(re.sub("([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove incomplete URL
    return text.replace("http://", " ").replace("https://", " ")
                
Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_review_text_special)

#remove number
def remove_number(text):
    return  re.sub(r"\d+", "", text)

Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_number)

#remove punctuation
def remove_punctuation(text):
    # hapus angka dan beberapa simbol
  text = re.sub('[^a-zA-Z,.?!]+',' ',text)
  return text

Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_punctuation)

#remove whitespace leading & trailing
def remove_whitespace_LT(text):
    return text.strip()

Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_whitespace_LT)

#remove multiple whitespace into single whitespace
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_whitespace_multiple)

# remove single char
def remove_singl_char(text):
    return re.sub(r"\b[a-zA-Z]\b", "", text)

Scrapped_Data['review_text'] = Scrapped_Data['review_text'].apply(remove_singl_char)

# NLTK word rokenize 
def word_tokenize_wrapper(text):
    return word_tokenize(text)

Scrapped_Data['review_text_tokens'] = Scrapped_Data['review_text'].apply(word_tokenize_wrapper)

print('Tokenizing Result : \n') 
print(Scrapped_Data['review_text_tokens'].head())
print('\n\n\n')
# Out:
# Tokenizing Result :
#
# 0    [halo, kak, mengasih, masuk, timbang, atur, uk...
# 1    [konten, download, putar, hubungi, admin, disn...
# 2    [sorry, tanya, kualitas, video, atur, mas, bur...
# 3    [ganti, resolusi, layar, hitam, film, mas, lan...
# 4    [install, aplikasi, rencana, menonton, series,...
# Name: review_text_tokens, dtype: object

# %%
from nltk.corpus import stopwords

# ----------------------- get stopword from NLTK stopword -------------------------------
# get stopword indonesia
list_stopwords = stopwords.words('indonesian')


# ---------------------------- manualy add stopword  ------------------------------------
# append additional stopword
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&amp', 'yah'])

# ----------------------- add stopword from txt file ------------------------------------
# read txt stopword using pandas
txt_stopword = pd.read_csv("/content/drive/MyDrive/asetskripsi/stopword2.txt", names= ["stopwords"], header = None)

# convert stopword string to list & append additional stopword
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))

# ---------------------------------------------------------------------------------------

# convert list to dictionary
list_stopwords = set(list_stopwords)


#remove stopword pada list token
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]

Scrapped_Data['review_text_tokens_WSW'] = Scrapped_Data['review_text_tokens'].apply(stopwords_removal) 


print(Scrapped_Data['review_text_tokens_WSW'].head())
# Out:
# 0    [halo, kak, mengasih, masuk, timbang, atur, uk...
# 1    [konten, download, putar, hubungi, admin, disn...
# 2    [sorry, kualitas, video, atur, mas, buram, hd,...
# 3    [ganti, resolusi, layar, hitam, film, mas, uni...
# 4    [install, aplikasi, rencana, menonton, series,...
# Name: review_text_tokens_WSW, dtype: object

# %%
pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.7/dist-packages (1.0.1)

# %%
pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: swifter in /usr/local/lib/python3.7/dist-packages (1.3.2)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.9.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: partd>=0.3.10 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.2.0)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2022.5.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.1)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.7/dist-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.16.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.8.1)

# %%
# import Sastrawi 
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in Scrapped_Data['review_text_tokens_WSW']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

Scrapped_Data['review_text_tokens_stemmed'] = Scrapped_Data['review_text_tokens_WSW'].swifter.apply(get_stemmed_term)
print(Scrapped_Data['review_text_tokens_stemmed'])
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# author : author
# tmksh : tmksh
# daerah : daerah
# inti : inti
# expirednya : expirednya
# mikir : mikir
# web : web
# thanks : thanks
# kunjung : kunjung
# upaya : upaya
# maksimum : maksimum
# muat : muat
# quota : quota
# dadak : dadak
# woy : woy
# bonus : bonus
# uang : uang
# senang : senang
# boros : boros
# sin : sin
# kuot : kuot
# karema : karema
# semi : semi
# ggu : ggu
# saran : saran
# center : center
# konsumen : konsumen
# lengkap : lengkap
# dikit : dikit
# berpikir : pikir
# auto : auto
# next : next
# scene : scene
# saldo : saldo
# pagi : pagi
# seluler : seluler
# adehhh : adehhh
# kouta : kouta
# ah : ah
# wkwkwkwk : wkwkwkwk
# sehat : sehat
# black : black
# bolak : bolak
# matiin : matiin
# seringkali : seringkali
# lte : lte
# lol : lol
# pixel : pixel
# pixelnya : pixelnya
# simpel : simpel
# stelan : stelan
# versi : versi
# mandolorian : mandolorian
# subs : subs
# sdm : sdm
# usil : usil
# improvisasi : improvisasi
# beranta : beranta
# sub : sub
# rang : rang
# site : site
# ui : ui
# benah : benah
# melayu : melayu
# masak : masak
# tibak : tibak
# blur : blur
# frame : frame
# perang : perang
# lsg : lsg
# bufering : bufering
# operator : operator
# malay : malay
# boooos : boooos
# edit : edit
# reting : reting
# minus : minus
# english : english
# title : title
# gede : gede
# minim : minim
# simpan : simpan
# microsd : microsd
# rekomendasi : rekomendasi
# jebol : jebol
# sulih : sulih
# jatuh : jatuh
# terjemah : terjemah
# akurat : akurat
# sekual : sekual
# karang : karang
# alam : alam
# plus : plus
# kendati : kendati
# ketimbang : ketimbang
# sebenernyamah : sebenernyamah
# radhakrishn : radhakrishn
# tamat : tamat
# annoying : annoying
# settingan : settingan
# bit : bit
# khusus : khusus
# brlangganan : brlangganan
# jarang : jarang
# why : why
# kwalitas : kwalitas
# ros : ros
# dubing : dubing
# utama : utama
# subtittle : subtittle
# trpksa : trpksa
# sent : sent
# screencast : screencast
# animasi : animasi
# lu : lu
# keren : keren
# sumpah : sumpah
# lgbt : lgbt
# selip : selip
# selipin : selipin
# kartun : kartun
# ngdoktrin : ngdoktrin
# simpang : simpang
# tangan : tangan
# default : default
# global : global
# proveder : proveder
# jaga : jaga
# konteks : konteks
# manual : manual
# mengomong : omong
# huruf : huruf
# ratus : ratus
# posisi : posisi
# wilayah : wilayah
# pulau : pulau
# sumatera : sumatera
# jawa : jawa
# force : force
# close : close
# mit : mit
# kecuali : kecuali
# subitle : subitle
# nyaingi : nyaingi
# yowisben : yowisben
# finale : finale
# ckckck : ckckck
# gaguna : gaguna
# freeze : freeze
# apps : apps
# hotstarnya : hotstarnya
# crash : crash
# hadeh : hadeh
# barusan : barusan
# darurat : darurat
# ketuk : ketuk
# logo : logo
# bahas : bahas
# oct : oct
# cahaya : cahaya
# resend : resend
# mayoritas : mayoritas
# taikkk : taikkk
# wa : wa
# percaya : percaya
# verifi : verifi
# tutorial : tutorial
# bareng : bareng
# upin : upin
# ipin : ipin
# dub : dub
# asli : asli
# ngelawak : ngelawak
# jul : jul
# oi : oi
# all : all
# ur : ur
# its : its
# not : not
# even : even
# alfamaret : alfamaret
# piye : piye
# dial : dial
# min : min
# aza : aza
# grafis : grafis
# kotak : kotak
# deskripsi : deskripsi
# playstore : playstore
# kambing : kambing
# dwload : dwload
# website : website
# ngirimin : ngirimin
# telfone : telfone
# seribet : seribet
# mubgkin : mubgkin
# jararingan : jararingan
# rewatch : rewatch
# wandavison : wandavison
# ws : ws
# chrome : chrome
# simpul : simpul
# vlive : vlive
# lola : lola
# kedengaran : dengar
# hibur : hibur
# keep : keep
# mendownload : mendownload
# notifikasi : notifikasi
# setia : setia
# maxstream : maxstream
# bgsd : bgsd
# translate : translate
# item : item
# ajg : ajg
# errror : errror
# premium : premium
# kgk : kgk
# anjr : anjr
# bapuk : bapuk
# tagih : tagih
# quality : quality
# netflixxxxxxxxxxxxx : netflixxxxxxxxxxxxx
# alfamart : alfamart
# kontollll : kontollll
# gratissss : gratissss
# goepy : goepy
# haduhh : haduhh
# butuh : butuh
# menit : menit
# emosi : emosi
# bosan : bosan
# ntn : ntn
# re : re
# relog : relog
# ram : ram
# memori : memori
# buanyak : buanyak
# kau : kau
# longor : longor
# uinstal : uinstal
# sampah : sampah
# jama : jama
# canggih : canggih
# norak : norak
# galeri : galeri
# gabung : gabung
# bnaget : bnaget
# ampun : ampun
# laaamaa : laaamaa
# mengkaibatkan : mengkaibatkan
# panas : panas
# total : total
# mendapati : dapat
# hft : hft
# bhsa : bhsa
# thailand : thailand
# bhasa : bhasa
# erti : erti
# silah : silah
# antre : antre
# copet : copet
# telkomselpun : telkomselpun
# lepas : lepas
# rusa : rusa
# rbu : rbu
# hadeehhh : hadeehhh
# pemberitahuan : pemberitahuan
# record : record
# ss : ss
# jangand : jangand
# blokir : blokir
# content : content
# creator : creator
# berlanggnan : berlanggnan
# nyq : nyq
# realme : realme
# dikecilin : dikecilin
# nontonya : nontonya
# asyik : asyik
# ngeblank : ngeblank
# busuk : busuk
# bubarin : bubarin
# tim : tim
# season : season
# resmi : resmi
# februari : februari
# internert : internert
# brand : brand
# becus : becus
# coa : coa
# yutub : yutub
# disetting : disetting
# mengdownload : mengdownload
# masukk : masukk
# downlod : downlod
# pelit : pelit
# haduuhh : haduuhh
# benner : benner
# ambil : ambil
# perbaikam : perbaikam
# stres : stres
# cs : cs
# siar : siar
# prabayar : prabayar
# kontrak : kontrak
# so : so
# pusing : pusing
# cerita : cerita
# playback : playback
# ngulang : ngulang
# stop : stop
# dinonton : dinonton
# bacan : bacan
# berlangana : berlangana
# fast : fast
# furious : furious
# jumanji : jumanji
# how : how
# train : train
# dragon : dragon
# berat : berat
# mendptkan : mendptkan
# streamingnya : streamingnya
# connect : connect
# tekor : tekor
# antri : antri
# memory : memory
# kosong : kosong
# filn : filn
# ribettt : ribettt
# signal : signal
# unisntal : unisntal
# notip : notip
# autentifikasi : autentifikasi
# mendownlod : mendownlod
# memyebalkan : memyebalkan
# store : store
# open : open
# more : more
# other : other
# versions : versions
# sep : sep
# komentar : komentar
# menyambung : sambung
# langsg : langsg
# sambung : sambung
# nampil : nampil
# dengar : dengar
# profile : profile
# foto : foto
# amerika : amerika
# jepang : jepang
# negara : negara
# ajar : ajar
# gmail : gmail
# timbulin : timbulin
# tuju : tuju
# tlg : tlg
# haduuh : haduuh
# bego : bego
# rela : rela
# user : user
# request : request
# kenpa : kenpa
# freze : freze
# moana : moana
# mulan : mulan
# soul : soul
# has : has
# occurred : occurred
# faq : faq
# unistall : unistall
# maxstreem : maxstreem
# utuh : utuh
# anycast : anycast
# barangkali : barangkali
# solasinya : solasinya
# yowis : yowis
# ben : ben
# tolonh : tolonh
# nexflix : nexflix
# makan : makan
# google : google
# supermarket : supermarket
# vidoenya : vidoenya
# ilangin : ilangin
# iconnya : iconnya
# merhatiin : merhatiin
# icon : icon
# hah : hah
# suda : suda
# klick : klick
# ganggua : ganggua
# virgin : virgin
# cinta : cinta
# umur : umur
# bla : bla
# arti : arti
# duit : duit
# membanyaki : banyak
# oh : oh
# wetv : wetv
# byara : byara
# gc : gc
# aaya : aaya
# menghilang : hilang
# mutar : mutar
# mac : mac
# oyaa : oyaa
# sisi : sisi
# nerima : nerima
# hud : hud
# wooi : wooi
# hai : hai
# siang : siang
# bulat : bulat
# biru : biru
# tahi : tahi
# bebas : bebas
# woee : woee
# lgin : lgin
# acara : acara
# attempt : attempt
# bnerin : bnerin
# nyusahin : nyusahin
# preorder : preorder
# bentuk : bentuk
# beta : beta
# lanjutin : lanjutin
# kacau : kacau
# udang : udang
# yaudah : yaudah
# pembayan : pembayan
# jembud : jembud
# buffer : buffer
# berlnggnan : berlnggnan
# cacatt : cacatt
# revisi : revisi
# loklok : loklok
# ngestuck : ngestuck
# sisa : sisa
# pakar : pakar
# volume : volume
# voice : voice
# musik : musik
# keras : keras
# ups : ups
# gun : gun
# ribut : ribut
# adu : adu
# berkas : berkas
# komplit : komplit
# mbak : mbak
# diupdate : diupdate
# lampir : lampir
# abai : abai
# seru : seru
# duluan : duluan
# gara : gara
# situs : situs
# jernih : jernih
# pahal : pahal
# murah : murah
# cuih : cuih
# tahub : tahub
# ponsel : ponsel
# heran : heran
# ngecrash : ngecrash
# appnya : appnya
# suck : suck
# wow : wow
# first : first
# impressionnya : impressionnya
# bobrok : bobrok
# amphibia : amphibia
# my : my
# telkompret : telkompret
# poco : poco
# phone : phone
# blackshark : blackshark
# sminggu : sminggu
# lamban : lamban
# jelekkkkkk : jelekkkkkk
# zoonk : zoonk
# ngapain : ngapain
# zonk : zonk
# thai : thai
# report : report
# indonya : indonya
# mengapai : kapai
# trouble : trouble
# iron : iron
# man : man
# orisinil : orisinil
# suport : suport
# sore : sore
# gapapa : gapapa
# bejat : bejat
# dongo : dongo
# ngising : ngising
# konek : konek
# timbul : timbul
# paham : paham
# sangan : sangan
# notif : notif
# lanngganan : lanngganan
# jringan : jringan
# sedot : sedot
# menunggu : tunggu
# seba : seba
# ngestak : ngestak
# banting : banting
# kloga : kloga
# dowload : dowload
# box : box
# flexible : flexible
# mbanking : mbanking
# dompet : dompet
# unistal : unistal
# tapu : tapu
# telfon : telfon
# pftt : pftt
# pler : pler
# servicenya : servicenya
# cok : cok
# masu : masu
# hotspot : hotspot
# laaa : laaa
# ramah : ramah
# disnes : disnes
# hoststar : hoststar
# autentikasi : autentikasi
# instalulang : instalulang
# kg : kg
# jadull : jadull
# when : when
# puluh : puluh
# buffring : buffring
# memperbaiki : baik
# huhuu : huhuu
# prettt : prettt
# aploud : aploud
# transaksi : transaksi
# pls : pls
# amt : amt
# putih : putih
# jamah : jamah
# feel : feel
# bro : bro
# ratatouille : ratatouille
# sensor : sensor
# send : send
# is : is
# too : too
# long : long
# wait : wait
# customer : customer
# gubris : gubris
# req : req
# text : text
# gratiss : gratiss
# tua : tua
# worth : worth
# stok : stok
# lawas : lawas
# kentang : kentang
# gadapet : gadapet
# developrler : developrler
# lebar : lebar
# mungkikah : mungkikah
# bijak : bijak
# malesiin : malesiin
# bgett : bgett
# hindustan : hindustan
# pliis : pliis
# hak : hak
# korea : korea
# chat : chat
# dibales : dibales
# untung : untung
# snowdrop : snowdrop
# subtitel : subtitel
# kadaluarsa : kadaluarsa
# trial : trial
# webos : webos
# inisiatif : inisiatif
# miracast : miracast
# puas : puas
# recomended : recomended
# advertising : advertising
# gembar : gembar
# gembor : gembor
# laden : laden
# jebluk : jebluk
# bangkrut : bangkrut
# juragan : juragan
# os : os
# merk : merk
# lanjur : lanjur
# sosmed : sosmed
# ngeblur : ngeblur
# resolution : resolution
# prematur : prematur
# bela : bela
# apk : apk
# nton : nton
# garis : garis
# tebal : tebal
# kontak : kontak
# reinstall : reinstall
# smap : smap
# stuck : stuck
# kenapaaa : kenapaaa
# balikin : balikin
# you : you
# are : are
# nyala : nyala
# off : off
# nak : nak
# top : top
# up : up
# samasekali : samasekali
# denfan : denfan
# nila : nila
# responnya : responnya
# duh : duh
# time : time
# rp : rp
# indomart : indomart
# feelnya : feelnya
# takut : takut
# koleksi : koleksi
# karya : karya
# original : original
# saing : saing
# nisa : nisa
# maxtream : maxtream
# satuh : satuh
# karenah : karenah
# langanan : langanan
# selam : selam
# cobah : cobah
# memuaska : memuaska
# janji : janji
# mengunakan : mengunakan
# ngapa : ngapa
# ngeplay : ngeplay
# kece : kece
# pokok : pokok
# maraton : maraton
# agent : agent
# of : of
# shield : shield
# pixar : pixar
# marvel : marvel
# alur : alur
# pis : pis
# panjangin : panjangin
# don : don
# this : this
# that : that
# intal : intal
# lan : lan
# ttel : ttel
# internetnya : internetnya
# prtma : prtma
# sngat : sngat
# ngedadak : ngedadak
# action : action
# advanture : advanture
# hororr : hororr
# tdinya : tdinya
# ngaruh : ngaruh
# usia : usia
# bangkai : bangkai
# fimlnya : fimlnya
# option : option
# bad : bad
# ratarata : ratarata
# bbrapa : bbrapa
# testi : testi
# benerbener : benerbener
# rekomen : rekomen
# kasitau : kasitau
# development : development
# perubaha : perubaha
# penuh : penuh
# show : show
# drastis : drastis
# waliing : waliing
# jenis : jenis
# kabar : kabar
# olshop : olshop
# selau : selau
# benci : benci
# mengaco : aco
# gapaham : gapaham
# kosakata : kosakata
# bo : bo
# ong : ong
# promo : promo
# kluarny : kluarny
# ntnnya : ntnnya
# soalny : soalny
# basi : basi
# korban : korban
# bijaksana : bijaksana
# adil : adil
# cerah : cerah
# neflix : neflix
# betenya : betenya
# search : search
# kerja : kerja
# akurasi : akurasi
# and : and
# then : then
# netflik : netflik
# applikasinya : applikasinya
# ndk : ndk
# agustus : agustus
# criminal : criminal
# minds : minds
# duga : duga
# btw : btw
# direspon : direspon
# devolper : devolper
# tiktok : tiktok
# instagram : instagram
# multimedia : multimedia
# tan : tan
# pantesan : pantesan
# jebak : jebak
# batman : batman
# faham : faham
# bertambah : tambah
# darting : darting
# besok : besok
# klao : klao
# iklas : iklas
# digunain : digunain
# grey : grey
# anatomy : anatomy
# eng : eng
# office : office
# gbnya : gbnya
# lenyap : lenyap
# darah : darah
# mesum : mesum
# ditayangkan : tayang
# bioskop : bioskop
# katun : katun
# menyebalkan : sebal
# subscene : subscene
# lumayan : lumayan
# file : file
# robot : robot
# tarik : tarik
# kesal : kesal
# ngehabisin : ngehabisin
# kzl : kzl
# ih : ih
# plz : plz
# optimal : optimal
# nomernya : nomernya
# include : include
# reviewnya : reviewnya
# china : china
# internetku : internetku
# bisaaa : bisaaa
# soundnya : soundnya
# problem : problem
# ddrm : ddrm
# neng : neng
# segitu : segitu
# but : but
# const : const
# curang : curang
# sizenya : sizenya
# nalar : nalar
# bom : bom
# nipu : nipu
# idh : idh
# bih : bih
# hard : hard
# sign : sign
# acc : acc
# page : page
# found : found
# akibat : akibat
# avatar : avatar
# buset : buset
# kawin : kawin
# jack : jack
# neytiri : neytiri
# bigini : bigini
# deadpool : deadpool
# fail : fail
# unstall : unstall
# overload : overload
# dibenerin : dibenerin
# yutube : yutube
# bening : bening
# beluk : beluk
# saaya : saaya
# pulsaa : pulsaa
# mirroring : mirroring
# efek : efek
# radiasi : radiasi
# sungguh : sungguh
# player : player
# private : private
# dns : dns
# telkom : telkom
# dalem : dalem
# air : air
# sidah : sidah
# network : network
# maxsteram : maxsteram
# tipe : tipe
# originalnya : originalnya
# njiiiirrr : njiiiirrr
# eeeeh : eeeeh
# jeleek : jeleek
# ngalahin : ngalahin
# hadeeeeeh : hadeeeeeh
# lempar : lempar
# minimum : minimum
# kec : kec
# ksel : ksel
# outomatis : outomatis
# hmm : hmm
# bahan : bahan
# dinaiikkan : dinaiikkan
# siput : siput
# buffernya : buffernya
# mandi : mandi
# tidur : tidur
# warning : warning
# responding : responding
# karnah : karnah
# tdi : tdi
# kerren : kerren
# bangun : bangun
# batang : batang
# dialfamart : dialfamart
# perintah : perintah
# donlod : donlod
# subtitelnya : subtitelnya
# oiya : oiya
# filmapik : filmapik
# eeh : eeh
# flim : flim
# maxtremnya : maxtremnya
# apes : apes
# bermamfaat : bermamfaat
# status : status
# menyarankan : saran
# rekomendasiiin : rekomendasiiin
# anjur : anjur
# dapa : dapa
# katro : katro
# what : what
# if : if
# blokkkkk : blokkkkk
# mantap : mantap
# makstreamnya : makstreamnya
# updatenya : updatenya
# confirmasi : confirmasi
# nontonin : nontonin
# dianey : dianey
# signalnya : signalnya
# bodong : bodong
# ngarap : ngarap
# hotin : hotin
# sebeelll : sebeelll
# adminnya : adminnya
# mmng : mmng
# andal : andal
# wlopun : wlopun
# ngambil : ngambil
# location : location
# conection : conection
# hallo : hallo
# enta : enta
# mitra : mitra
# wilaya : wilaya
# kompeten : kompeten
# pers : pers
# simpati : simpati
# regular : regular
# woooiiii : woooiiii
# tercover : tercover
# pergi : pergi
# dunia : dunia
# hotsar : hotsar
# wtf : wtf
# didonlot : didonlot
# diinput : diinput
# takk : takk
# huh : huh
# dysney : dysney
# kapok : kapok
# ngelanjutin : ngelanjutin
# grapari : grapari
# durasi : durasi
# singapur : singapur
# flimnya : flimnya
# radha : radha
# krisna : krisna
# tanggung : tanggung
# tayangin : tayangin
# berlanganan : berlanganan
# marah : marah
# nyedot : nyedot
# reguler : reguler
# playing : playing
# due : due
# try : try
# again : again
# res : res
# membelikan : beli
# quotanya : quotanya
# samo : samo
# mencet : mencet
# terjaji : terjaji
# gimanasih : gimanasih
# stuttering : stuttering
# mid : mid
# end : end
# persetan : persetan
# googling : googling
# radhakrisna : radhakrisna
# marvels : marvels
# beres : beres
# benrin : benrin
# troubel : troubel
# bandingin : bandingin
# rival : rival
# ning : ning
# jeleekk : jeleekk
# mandarin : mandarin
# lucu : lucu
# karakter : karakter
# logat : logat
# allah : allah
# his : his
# dimytelkomsel : dimytelkomsel
# legal : legal
# tidakbisa : tidakbisa
# dengen : dengen
# netfl : netfl
# tidk : tidk
# manfaat : manfaat
# tudak : tudak
# brengsek : brengsek
# didelet : didelet
# bicara : bicara
# monopoli : monopoli
# variasi : variasi
# amazon : amazon
# prime : prime
# beberpa : beberpa
# disneyplus : disneyplus
# id : id
# filem : filem
# faforit : faforit
# lodingnya : lodingnya
# filemnya : filemnya
# ekspektasi : ekspektasi
# doogle : doogle
# toling : toling
# memilih : pilih
# suarany : suarany
# ngabisin : ngabisin
# negeri : negeri
# dlam : dlam
# banyar : banyar
# hmmm : hmmm
# komen : komen
# lamaaa : lamaaa
# message : message
# siih : siih
# ngandalkan : ngandalkan
# nyalain : nyalain
# bagusin : bagusin
# pertahanin : pertahanin
# mytsel : mytsel
# gadget : gadget
# fb : fb
# ig : ig
# tik : tik
# tok : tok
# gmbr : gmbr
# ngebatalin : ngebatalin
# donlot : donlot
# oops : oops
# sometime : sometime
# mubazir : mubazir
# batrei : batrei
# mengeluarkan : keluar
# kakak : kakak
# form : form
# aktivinnya : aktivinnya
# sktr : sktr
# omg : omg
# by : by
# mengomongnya : omong
# motong : motong
# sory : sory
# youtobe : youtobe
# nala : nala
# dibalikin : dibalikin
# pay : pay
# extra : extra
# vodeonya : vodeonya
# lansung : lansung
# kuata : kuata
# jls : jls
# krishna : krishna
# cumann : cumann
# dotonton : dotonton
# oakek : oakek
# pulsaaa : pulsaaa
# dpet : dpet
# diribetkan : diribetkan
# ngirimkan : ngirimkan
# hq : hq
# waduuhhh : waduuhhh
# apesss : apesss
# musti : musti
# nolong : nolong
# kuta : kuta
# radhakrishna : radhakrishna
# potonganya : potonganya
# krishnanya : krishnanya
# bentar : bentar
# gam : gam
# mbgkin : mbgkin
# seasonnya : seasonnya
# truss : truss
# hindia : hindia
# gadak : gadak
# serius : serius
# makenya : makenya
# hadeehh : hadeehh
# pasnyari : pasnyari
# referensi : referensi
# dwnld : dwnld
# yowes : yowes
# version : version
# versionnya : versionnya
# gps : gps
# retry : retry
# simpsons : simpsons
# favorit : favorit
# blackscreen : blackscreen
# pandang : pandang
# kasta : kasta
# warga : warga
# rb : rb
# huawei : huawei
# iflix : iflix
# service : service
# noh : noh
# va : va
# mandiri : mandiri
# konfirmasi : konfirmasi
# kredibilitas : kredibilitas
# repot : repot
# instal : instal
# wkwkkwkwkwk : wkwkkwkwkwk
# cobain : cobain
# senyeselnya : senyeselnya
# centernya : centernya
# aps : aps
# valid : valid
# paketin : paketin
# duannya : duannya
# habisin : habisin
# booong : booong
# maket : maket
# asing : asing
# nyata : nyata
# oiiii : oiiii
# sukses : sukses
# menginstal : menginstal
# amet : amet
# kalunya : kalunya
# temen : temen
# teman : teman
# kompensasi : kompensasi
# mengetik : etik
# doangg : doangg
# keburu : keburu
# konglomerat : konglomerat
# hedeeehhh : hedeeehhh
# nyediain : nyediain
# kuras : kuras
# real : real
# dise : dise
# gan : gan
# broo : broo
# biat : biat
# jelasin : jelasin
# wkwkwk : wkwkwk
# landscape : landscape
# split : split
# diutak : diutak
# maf : maf
# unlimitedmax : unlimitedmax
# jaa : jaa
# bbrpa : bbrpa
# vip : vip
# upade : upade
# lagiasyik : lagiasyik
# nonnton : nonnton
# max : max
# treamnya : treamnya
# wakwak : wakwak
# sikat : sikat
# nol : nol
# dilaporin : dilaporin
# cekidot : cekidot
# mengatur : atur
# pulang : pulang
# internasional : internasional
# rcti : rcti
# stream : stream
# alangkah : alangkah
# kaget : kaget
# ngeframe : ngeframe
# nov : nov
# falcon : falcon
# winter : winter
# soldier : soldier
# hadeeh : hadeeh
# dimana : mana
# pubg : pubg
# cod : cod
# ml : ml
# tele : tele
# pembayaranya : pembayaranya
# ple : ple
# kredi : kredi
# soaalnya : soaalnya
# channel : channel
# mandalorian : mandalorian
# inhuman : inhuman
# discontinue : discontinue
# wars : wars
# men : men
# promosi : promosi
# apkliasi : apkliasi
# fox : fox
# movies : movies
# pusat : pusat
# asia : asia
# jadul : jadul
# bisnis : bisnis
# debitt : debitt
# susahh : susahh
# diikutin : diikutin
# step : step
# gaptek : gaptek
# sampee : sampee
# kesell : kesell
# mngapa : mngapa
# php : php
# msak : msak
# dongle : dongle
# maricast : maricast
# kelola : kelola
# uud : uud
# fiperbaiki : fiperbaiki
# ara : ara
# mengadakan : ada
# dm : dm
# twitter : twitter
# tindak : tindak
# cb : cb
# inten : inten
# jaringanny : jaringanny
# follow : follow
# pop : pop
# eternal : eternal
# hati : hati
# bisanonton : bisanonton
# menampak : tampak
# ngotak : ngotak
# anjing : anjing
# cman : cman
# gratia : gratia
# die : die
# wifii : wifii
# lk : lk
# mulus : mulus
# nginstal : nginstal
# harusbpakai : harusbpakai
# maxstreamnya : maxstreamnya
# tenggang : tenggang
# at : at
# least : least
# substitle : substitle
# piihan : piihan
# ipad : ipad
# filim : filim
# bayak : bayak
# dwonload : dwonload
# ofline : ofline
# kelar : kelar
# sbnere : sbnere
# bgmna : bgmna
# byar : byar
# lngganan : lngganan
# fyi : fyi
# permisi : permisi
# televisi : televisi
# program : program
# complain : complain
# aplgi : aplgi
# rekening : rekening
# pedahal : pedahal
# koordinasi : koordinasi
# santai : santai
# aktiftan : aktiftan
# chemistry : chemistry
# kere : kere
# gerat : gerat
# bgi : bgi
# pakenya : pakenya
# pleasr : pleasr
# umr : umr
# haru : haru
# redit : redit
# minjem : minjem
# pacar : pacar
# ikit : ikit
# parahhh : parahhh
# fps : fps
# uppss : uppss
# uldah : uldah
# perdana : perdana
# biaa : biaa
# dowlod : dowlod
# buriq : buriq
# unsubs : unsubs
# diup : diup
# muluu : muluu
# fan : fan
# direkomen : direkomen
# senelah : senelah
# weh : weh
# ter : ter
# prank : prank
# judul : judul
# mumpuni : mumpuni
# bneer : bneer
# playernya : playernya
# histori : histori
# disediakn : disediakn
# boro : boro
# murahin : murahin
# mentok : mentok
# indenesia : indenesia
# kosa : kosa
# proyektor : proyektor
# wireless : wireless
# wandavision : wandavision
# me : me
# dpmm : dpmm
# bulqn : bulqn
# rena : rena
# danjuga : danjuga
# sainganya : sainganya
# yesel : yesel
# ngingati : ngingati
# plat : plat
# merah : merah
# malu : malu
# subtitles : subtitles
# appsnya : appsnya
# brows : brows
# loki : loki
# orginal : orginal
# suit : suit
# life : life
# zack : zack
# cody : cody
# reply : reply
# fak : fak
# bgok : bgok
# subtittlenya : subtittlenya
# thx : thx
# bngsatt : bngsatt
# pluss : pluss
# rampok : rampok
# seka : seka
# anjjing : anjjing
# link : link
# applikasi : applikasi
# skema : skema
# ngegame : ngegame
# trdaftar : trdaftar
# interner : interner
# trpotong : trpotong
# cantik : cantik
# temu : temu
# cartoon : cartoon
# nyuruh : nyuruh
# ges : ges
# hayalan : hayalan
# gratisny : gratisny
# siallllll : siallllll
# visa : visa
# cita : cita
# lbgt : lbgt
# najis : najis
# ccd : ccd
# ngentod : ngentod
# harry : harry
# potter : potter
# nongol : nongol
# strange : strange
# qualitas : qualitas
# terap : terap
# rentang : rentang
# sebal : sebal
# lazim : lazim
# us : us
# chromecast : chromecast
# keteranganny : keteranganny
# diaktivkan : diaktivkan
# tetangga : tetangga
# browsing : browsing
# tablet : tablet
# table : table
# potrait : potrait
# indonesa : indonesa
# negar : negar
# terupdate : terupdate
# laga : laga
# nampilin : nampilin
# mail : mail
# atapun : atapun
# telephone : telephone
# dartar : dartar
# splikasi : splikasi
# ketik : ketik
# swmpat : swmpat
# ams : ams
# sakit : sakit
# hijau : hijau
# alih : alih
# somehing : somehing
# emnag : emnag
# padhaal : padhaal
# celular : celular
# hpku : hpku
# adapani : adapani
# walayah : walayah
# buru : buru
# karnakan : karnakan
# laut : laut
# py : py
# sd : sd
# huhuhu : huhuhu
# guy : guy
# buln : buln
# maruk : maruk
# pembyrannya : pembyrannya
# krrdit : krrdit
# berlngganan : berlngganan
# kebanyakn : kebanyakn
# dolby : dolby
# atmos : atmos
# ayar : ayar
# share : share
# streamong : streamong
# wifinya : wifinya
# tb : tb
# bknnya : bknnya
# hotstart : hotstart
# buffrering : buffrering
# broken : broken
# direstart : direstart
# logika : logika
# taut : taut
# contak : contak
# kaguya : kaguya
# diary : diary
# prosecutor : prosecutor
# samping : samping
# saji : saji
# hadeuuuh : hadeuuuh
# xl : xl
# experience : experience
# du : du
# kereset : kereset
# ngaak : ngaak
# pisah : pisah
# hadeeeh : hadeeeh
# freazz : freazz
# mentokin : mentokin
# hadeuh : hadeuh
# fungsinga : fungsinga
# virus : virus
# loggin : loggin
# kulitas : kulitas
# ampuunnn : ampuunnn
# komputer : komputer
# kompi : kompi
# kepala : kepala
# arrghh : arrghh
# dwonglod : dwonglod
# dikirimin : dikirimin
# genre : genre
# horror : horror
# kes : kes
# peran : peran
# jiwa : jiwa
# semntara : semntara
# signifikan : signifikan
# voucher : voucher
# kk : kk
# sebelumny : sebelumny
# lainny : lainny
# skrng : skrng
# kl : kl
# mksh : mksh
# apdate : apdate
# gi : gi
# uinya : uinya
# list : list
# menutupi : tutup
# gonta : gonta
# forward : forward
# backward : backward
# cenderung : cenderung
# murni : murni
# enjoyable : enjoyable
# kreasi : kreasi
# kendali : kendali
# loadout : loadout
# nayangin : nayangin
# spyxfamily : spyxfamily
# last : last
# hadehh : hadehh
# anget : anget
# buatblangganan : buatblangganan
# loadiing : loadiing
# ix : ix
# biso : biso
# pegenya : pegenya
# button : button
# size : size
# super : super
# ilegal : ilegal
# dilengkapin : dilengkapin
# minimal : minimal
# kadaluwarsanya : kadaluwarsanya
# kadaluwarsa : kadaluwarsa
# sisih : sisih
# prioritas : prioritas
# maksudx : maksudx
# slow : slow
# mini : mini
# trsannn : trsannn
# diperbaikin : diperbaikin
# gj : gj
# epnya : epnya
# gajeeeeeeeeeeeeeeerrr : gajeeeeeeeeeeeeeeerrr
# wib : wib
# facebook : facebook
# ngilangin : ngilangin
# coming : coming
# soon : soon
# avengers : avengers
# jenuh : jenuh
# tks : tks
# desain : desain
# sederhana : sederhana
# seri : seri
# tampilanya : tampilanya
# nemu : nemu
# tanda : tanda
# tmn : tmn
# let : let
# rave : rave
# menikmati : nikmat
# jeda : jeda
# novel : novel
# polytron : polytron
# nyepetin : nyepetin
# diomongin : diomongin
# terimakasi : terimakasi
# multibillion : multibillion
# dollar : dollar
# uras : uras
# baterai : baterai
# opini : opini
# pribadi : pribadi
# patok : patok
# edge : edge
# filmnya : film
# brlngganan : brlngganan
# mlulu : mlulu
# tolongny : tolongny
# percpt : percpt
# actionnya : actionnya
# avenger : avenger
# dkk : dkk
# lengkapp : lengkapp
# lengkapn : lengkapn
# jos : jos
# inh : inh
# lagih : lagih
# judull : judull
# ibgin : ibgin
# smooth : smooth
# pass : pass
# smarttv : smarttv
# ngungsi : ngungsi
# biarpun : biarpun
# ujung : ujung
# gel : gel
# whatsapp : whatsapp
# official : official
# dual : dual
# messanger : messanger
# lamaaaa : lamaaaa
# eeeh : eeeh
# kedip : kedip
# sebel : sebel
# webtv : webtv
# penasaran : penasaran
# viral : viral
# pesawat : pesawat
# non : non
# rame : rame
# keluarga : keluarga
# tq : tq
# kabel : kabel
# hdmi : hdmi
# hemat : hemat
# sony : sony
# xperia : xperia
# tingi : tingi
# dibyr : dibyr
# diblas : diblas
# sanggup : sanggup
# dil : dil
# milea : milea
# tanding : tanding
# konekin : konekin
# leletnyaa : leletnyaa
# evaluasi : evaluasi
# rekom : rekom
# tingggiin : tingggiin
# ecek : ecek
# huufftt : huufftt
# twitch : twitch
# etc : etc
# lancara : lancara
# lowest : lowest
# dtingkatkan : dtingkatkan
# performa : performa
# turunin : turunin
# bundling : bundling
# kmarin : kmarin
# travelling : travelling
# hack : hack
# hdr : hdr
# tingkatin : tingkatin
# muterrrr : muterrrr
# dendam : dendam
# sebnernya : sebnernya
# yeeh : yeeh
# tolonngah : tolonngah
# sombong : sombong
# aga : aga
# selancar : selancar
# mengkustomisasi : mengkustomisasi
# ngedown : ngedown
# yauda : yauda
# tnyata : tnyata
# pembayarannnya : pembayarannnya
# diblock : diblock
# crome : crome
# gerak : gerak
# selang : selang
# pc : pc
# expired : expired
# hangus : hangus
# jk : jk
# date : date
# gugur : gugur
# tvnya : tvnya
# change : change
# country : country
# nginstall : nginstall
# once : once
# namatin : namatin
# pasal : pasal
# horrornya : horrornya
# unfaedah : unfaedah
# horor : horor
# laun : laun
# lnjut : lnjut
# mncul : mncul
# syarat : syarat
# scroll : scroll
# bwah : bwah
# thnks : thnks
# internal : internal
# ngebut : ngebut
# adik : adik
# antusias : antusias
# rasio : rasio
# letak : letak
# hollywood : hollywood
# cut : cut
# ranah : ranah
# pasang : pasang
# agresif : agresif
# liar : liar
# nunjukkin : nunjukkin
# mengesalkan : kesal
# tiktod : tiktod
# tiru : tiru
# overall : overall
# nyama : nyama
# dubbingnya : dubbingnya
# printah : printah
# lupa : lupa
# replay : replay
# komedian : komedian
# diupload : diupload
# penanyangan : penanyangan
# daya : daya
# kallaunya : kallaunya
# berlangg : berlangg
# tailer : tailer
# motar : motar
# telko : telko
# sel : sel
# langga : langga
# ing : ing
# ngobrol : ngobrol
# homescreen : homescreen
# disneyhotstar : disneyhotstar
# rapi : rapi
# telokomsel : telokomsel
# pagus : pagus
# maxsrtream : maxsrtream
# om : om
# regiler : regiler
# serba : serba
# fullscreen : fullscreen
# dinhp : dinhp
# aspek : aspek
# rationya : rationya
# castle : castle
# juli : juli
# updaet : updaet
# mendownloadnya : mendownloadnya
# as : as
# possible : possible
# waiting : waiting
# answer : answer
# semuaa : semuaa
# bolehin : bolehin
# http : http
# injector : injector
# izin : izin
# pre : pre
# order : order
# haji : haji
# subscription : subscription
# standar : standar
# gim : gim
# andorid : andorid
# com : com
# activate : activate
# launching : launching
# rabu : rabu
# oktober : oktober
# muterin : muterin
# hitung : hitung
# promon : promon
# ancyur : ancyur
# teruuuss : teruuuss
# stlh : stlh
# kolom : kolom
# whaa : whaa
# brrti : brrti
# ngalamin : ngalamin
# miiin : miiin
# fidionya : fidionya
# waguuuh : waguuuh
# jlas : jlas
# tabung : tabung
# kedang : kedang
# lagging : lagging
# galaxy : galaxy
# yekaliiii : yekaliiii
# sawadikap : sawadikap
# sawah : sawah
# cup : cup
# tips : tips
# lamaa : lamaa
# analisa : analisa
# susa : susa
# muncu : muncu
# tilusan : tilusan
# kesalhan : kesalhan
# nm : nm
# lsng : lsng
# diseny : diseny
# rangin : rangin
# yasa : yasa
# perotes : perotes
# sutitel : sutitel
# sudtitel : sudtitel
# karana : karana
# kecepetan : kecepetan
# dipaksain : dipaksain
# bsia : bsia
# nnt : nnt
# berlanggana : berlanggana
# bablas : bablas
# kiri : kiri
# kanan : kanan
# area : area
# ngblank : ngblank
# luas : luas
# sambungin : sambungin
# pkonya : pkonya
# starvision : starvision
# dibanyakin : dibanyakin
# gembell : gembell
# telegram : telegram
# flashnya : flashnya
# maxsteam : maxsteam
# ragu : ragu
# ngumpulin : ngumpulin
# balesan : balesan
# doi : doi
# warung : warung
# kopi : kopi
# dki : dki
# reborn : reborn
# cars : cars
# panther : panther
# sehhhh : sehhhh
# anjerrr : anjerrr
# rebu : rebu
# flagship : flagship
# can : can
# process : process
# indosat : indosat
# barat : barat
# rosemary : rosemary
# baby : baby
# omen : omen
# sdngkn : sdngkn
# gpny : gpny
# dibnrin : dibnrin
# good : good
# draemworks : draemworks
# neko : neko
# simpson : simpson
# batal : batal
# madagascar : madagascar
# tlng : tlng
# format : format
# jamin : jamin
# rotate : rotate
# ngeloading : ngeloading
# menindaklanjuti : menindaklanjuti
# tlong : tlong
# animenya : animenya
# ditambahin : ditambahin
# inggin : inggin
# bt : bt
# dubb : dubb
# hadeuhh : hadeuhh
# ngedalam : ngedalam
# kemudianberkurang : kemudianberkurang
# kawan : kawan
# linimasa : linimasa
# notifnya : notifnya
# terims : terims
# salam : salam
# nunngu : nunngu
# september : september
# medioker : medioker
# gopi : gopi
# uttaran : uttaran
# balika : balika
# vadhu : vadhu
# dihp : dihp
# jahat : jahat
# agust : agust
# sept : sept
# anee : anee
# pemnayaran : pemnayaran
# loginnya : loginnya
# abis : abis
# nonton : nonton
# bosen : bosen
# betah : betah
# greenscreen : greenscreen
# lebel : lebel
# editt : editt
# lagiiiiiii : lagiiiiiii
# terakhirrrrr : terakhirrrrr
# gadaa : gadaa
# gambarrrr : gambarrrr
# layarrrrr : layarrrrr
# hijauuuuuuuu : hijauuuuuuuu
# comment : comment
# oper : oper
# tolongg : tolongg
# jwabb : jwabb
# loginin : loginin
# cancel : cancel
# jwab : jwab
# benr : benr
# downnload : downnload
# chromcastnya : chromcastnya
# nex : nex
# toggle : toggle
# zoom : zoom
# tinggu : tinggu
# jelk : jelk
# yasudah : yasudah
# maafmin : maafmin
# minn : minn
# makasihh : makasihh
# koo : koo
# tranvision : tranvision
# extrem : extrem
# bufferimg : bufferimg
# shang : shang
# chi : chi
# november : november
# alasanya : alasanya
# filmya : filmya
# samapi : samapi
# studio : studio
# anehh : anehh
# lanjutinnya : lanjutinnya
# nyendat : nyendat
# ce : ce
# haroo : haroo
# haroooo : haroooo
# kpop : kpop
# latar : latar
# hei : hei
# tonlong : tonlong
# vangkee : vangkee
# maxtsream : maxtsream
# binggung : binggung
# ngerekam : ngerekam
# raya : raya
# moviiesnya : moviiesnya
# berlanggann : berlanggann
# apss : apss
# dicepetin : dicepetin
# encanto : encanto
# dreamworks : dreamworks
# munculin : munculin
# kungfupanda : kungfupanda
# manteman : manteman
# developper : developper
# profil : profil
# amattt : amattt
# artemis : artemis
# fowl : fowl
# huft : huft
# seseason : seseason
# ultimate : ultimate
# audah : audah
# srh : srh
# blnan : blnan
# gra : gra
# metodi : metodi
# smaa : smaa
# videox : videox
# conect : conect
# diberitahukan : diberitahukan
# adohhhhh : adohhhhh
# baikin : baikin
# tittle : tittle
# jalur : jalur
# fahan : fahan
# les : les
# atuhh : atuhh
# cobak : cobak
# mainin : mainin
# subindonya : subindonya
# bagua : bagua
# cust : cust
# males : males
# kaku : kaku
# telenovela : telenovela
# bgaimana : bgaimana
# sebener : sebener
# papa : papa
# ngak : ngak
# turutin : turutin
# trimakasih : trimakasih
# varian : varian
# tamil : tamil
# katany : katany
# cruella : cruella
# jang : jang
# pengupdatean : pengupdatean
# didiemin : didiemin
# troublenya : troublenya
# bawa : bawa
# filemya : filemya
# keluwar : keluwar
# peyimpanan : peyimpanan
# ful : ful
# soalnta : soalnta
# dominan : dominan
# pby : pby
# mi : mi
# pencerahanya : pencerahanya
# bintanng : bintanng
# plisss : plisss
# toejoe : toejoe
# angin : angin
# cepetin : cepetin
# meng : meng
# miracastnya : miracastnya
# lobby : lobby
# refresh : refresh
# recent : recent
# hoki : hoki
# brkali : brkali
# oppo : oppo
# pub : pub
# cloud : cloud
# diupate : diupate
# timpa : timpa
# tumpang : tumpang
# tindih : tindih
# model : model
# jrg : jrg
# bermslh : bermslh
# kemana : mana
# helllo : helllo
# subtle : subtle
# kenderaan : kenderaan
# intro : intro
# maxtreamnya : maxtreamnya
# swlalu : swlalu
# oopss : oopss
# padah : padah
# jmlah : jmlah
# pket : pket
# tawarin : tawarin
# tawar : tawar
# dpat : dpat
# ain : ain
# terstuck : terstuck
# modal : modal
# trnyta : trnyta
# banggan : banggan
# nerimanya : nerimanya
# taikk : taikk
# pasir : pasir
# terussss : terussss
# po : po
# hrsnya : hrsnya
# berngganan : berngganan
# subscribe : subscribe
# bayarrrr : bayarrrr
# jdinya : jdinya
# runyem : runyem
# miroring : miroring
# nonto : nonto
# ruang : ruang
# cuwepet : cuwepet
# woelah : woelah
# junior : junior
# brenti : brenti
# sofia : sofia
# adakan : adakan
# tolak : tolak
# daftarin : daftarin
# susahmasuk : susahmasuk
# mahalll : mahalll
# bngttttt : bngttttt
# mahall : mahall
# mnjdi : mnjdi
# tiddak : tiddak
# trlanjur : trlanjur
# hbskan : hbskan
# gmbar : gmbar
# nf : nf
# lenkap : lenkap
# ditanggapin : ditanggapin
# thankyou : thankyou
# pembyaaran : pembyaaran
# continue : continue
# gambarutar : gambarutar
# deg : deg
# popup : popup
# background : background
# pantat : pantat
# dowloand : dowloand
# hoster : hoster
# cinematic : cinematic
# universe : universe
# disnet : disnet
# ber : ber
# eternals : eternals
# udah : udah
# fiks : fiks
# rebels : rebels
# mngkn : mngkn
# tersamhung : tersamhung
# kasiih : kasiih
# diapk : diapk
# mariculous : mariculous
# ladybug : ladybug
# egak : egak
# window : window
# lemah : lemah
# mutarnya : mutarnya
# fails : fails
# initiate : initiate
# tld : tld
# terlogout : terlogout
# terdelete : terdelete
# verificationnya : verificationnya
# chanel : chanel
# sport : sport
# motogp : motogp
# wsbk : wsbk
# kabur : kabur
# tingga : tingga
# loop : loop
# assalamualaikum : assalamualaikum
# oky : oky
# wassalamu : wassalamu
# alaikum : alaikum
# sunshine : sunshine
# efisien : efisien
# after : after
# dikonformasi : dikonformasi
# hk : hk
# krim : krim
# kuar : kuar
# gprs : gprs
# serverny : serverny
# get : get
# andai : andai
# tungguin : tungguin
# adaaa : adaaa
# tolomg : tolomg
# check : check
# manager : manager
# dar : dar
# smsnya : smsnya
# sebutin : sebutin
# angka : angka
# mira : mira
# ast : ast
# lix : lix
# suguh : suguh
# epsdnya : epsdnya
# dkit : dkit
# mandaloarian : mandaloarian
# bahada : bahada
# wasting : wasting
# dsuruh : dsuruh
# infonha : infonha
# setiyap : setiyap
# tukar : tukar
# poin : poin
# gondok : gondok
# mggu : mggu
# perceminan : perceminan
# enggk : enggk
# pnjelasan : pnjelasan
# mssih : mssih
# bia : bia
# indianya : indianya
# rap : rap
# rada : rada
# graaatis : graaatis
# lur : lur
# gamasuk : gamasuk
# drsma : drsma
# cina : cina
# epi : epi
# sod : sod
# tampa : tampa
# cape : cape
# tekxs : tekxs
# aah : aah
# sembarang : sembarang
# menyesak : sesak
# belipaket : belipaket
# melurfirdaus : melurfirdaus
# notification : notification
# spidermannya : spidermannya
# tahan : tahan
# donwloand : donwloand
# grtis : grtis
# wkwk : wkwk
# hedeh : hedeh
# bngsat : bngsat
# malware : malware
# curiga : curiga
# smartfreen : smartfreen
# pulng : pulng
# dek : dek
# apai : apa
# katnya : katnya
# mu : mu
# gabsia : gabsia
# dsruh : dsruh
# woii : woii
# woyyyy : woyyyy
# lewar : lewar
# updat : updat
# broh : broh
# sarat : sarat
# sh : sh
# ye : ye
# sampei : sampei
# upde : upde
# upd : upd
# gth : gth
# ops : ops
# nelpon : nelpon
# mirrroring : mirrroring
# head : head
# unit : unit
# mobil : mobil
# sak : sak
# habsi : habsi
# ngehate : ngehate
# sangatt : sangatt
# hms : hms
# bollywood : bollywood
# sbnrnya : sbnrnya
# sblmnya : sblmnya
# memkasa : memkasa
# arus : arus
# pembyranx : pembyranx
# plan : plan
# hx : hx
# atm : atm
# response : response
# diresponse : diresponse
# triler : triler
# cuk : cuk
# desember : desember
# ampas : ampas
# cmb : cmb
# kgitu : kgitu
# story : story
# kuslitas : kuslitas
# autoplay : autoplay
# galengkap : galengkap
# terusannyalagi : terusannyalagi
# puasa : puasa
# kenanyakan : kenanyakan
# ndonlod : ndonlod
# jelekdeh : jelekdeh
# pikr : pikr
# sanpai : sanpai
# ampuuuunn : ampuuuunn
# bogeng : bogeng
# ngutamain : ngutamain
# plisssss : plisssss
# gartis : gartis
# miraculous : miraculous
# garap : garap
# bingunh : bingunh
# owl : owl
# house : house
# hiatus : hiatus
# lwat : lwat
# ditunggu : tunggu
# ksalahn : ksalahn
# untum : untum
# terinstal : terinstal
# ti : ti
# berlanggaan : berlanggaan
# kedengeran : kedengeran
# gimana : gimana
# berki : berki
# sebelll : sebelll
# playable : playable
# mui : mui
# rupa : rupa
# mahabarta : mahabarta
# joda : joda
# akbar : akbar
# shopepay : shopepay
# rinci : rinci
# segi : segi
# jangkau : jangkau
# earphone : earphone
# cema : cema
# pesat : pesat
# hostarnya : hostarnya
# gambanya : gambanya
# tenggara : tenggara
# leptop : leptop
# ufah : ufah
# kdg : kdg
# sadar : sadar
# terdownload : terdownload
# mentang : mentang
# melallui : melallui
# dlsb : dlsb
# rakyat : rakyat
# neka : neka
# apalh : apalh
# bag : bag
# hade : hade
# gp : gp
# uji : uji
# sabar : sabar
# lengkapin : lengkapin
# flash : flash
# green : green
# arrow : arrow
# tdak : tdak
# inet : inet
# ff : ff
# fixed : fixed
# ding : ding
# demen : demen
# kiss : kiss
# sixth : sixth
# sense : sense
# input : input
# fungi : fungi
# ngubah : ngubah
# prah : prah
# sbntr : sbntr
# kompres : kompres
# verse : verse
# spider : spider
# kumplit : kumplit
# semja : semja
# toby : toby
# vesi : vesi
# ugh : ugh
# bersih : bersih
# pouse : pouse
# getar : getar
# disnye : disnye
# dioerbaiki : dioerbaiki
# beberaap : beberaap
# argh : argh
# ksl : ksl
# biaan : biaan
# kurg : kurg
# pagenya : pagenya
# lang : lang
# taruh : taruh
# teh : teh
# seris : seris
# pelang : pelang
# dioptimalin : dioptimalin
# tlpn : tlpn
# inbox : inbox
# validasi : validasi
# pedih : pedih
# fa : fa
# gaya : gaya
# menelvon : menelvon
# angkat : angkat
# halaman : halaman
# ngerewacth : ngerewacth
# american : american
# language : language
# gera : gera
# ngadet : ngadet
# didenger : didenger
# kontras : kontras
# crosscheck : crosscheck
# motion : motion
# kimetsu : kimetsu
# yaiba : yaiba
# kkn : kkn
# tari : tari
# ditawarin : ditawarin
# grid : grid
# system : system
# kas : kas
# tada : tada
# memlih : memlih
# dasayakeadaan : dasayakeadaan
# lantas : lantas
# gesture : gesture
# sesi : sesi
# diap : diap
# trsss : trsss
# huwaaaa : huwaaaa
# spesifik : spesifik
# pocong : pocong
# origin : origin
# subb : subb
# kga : kga
# sesuaiin : sesuaiin
# actor : actor
# seriesnya : seriesnya
# running : running
# well : well
# bantuanya : bantuanya
# far : far
# mrnyambung : mrnyambung
# ngedetect : ngedetect
# mirorlink : mirorlink
# rick : rick
# tumbnailnya : tumbnailnya
# tumbnail : tumbnail
# donald : donald
# duck : duck
# summer : summer
# render : render
# kno : kno
# lsin : lsin
# kocak : kocak
# mentonon : mentonon
# market : market
# mudahin : mudahin
# pembyaran : pembyaran
# ingris : ingris
# ngmong : ngmong
# mirroringnya : mirroringnya
# cleardata : cleardata
# buttonnya : buttonnya
# kasoh : kasoh
# oastu : oastu
# diskriminasi : diskriminasi
# muncil : muncil
# level : level
# kutu : kutu
# buku : buku
# bulannnya : bulannnya
# hadir : hadir
# rpk : rpk
# langkah : langkah
# ramban : ramban
# kombinasi : kombinasi
# switch : switch
# keyboard : keyboard
# nonaktif : nonaktif
# vertifikadi : vertifikadi
# paki : paki
# jancom : jancom
# ngeganggu : ngeganggu
# timer : timer
# semangat : semangat
# untu : untu
# sang : sang
# kiai : kiai
# vcd : vcd
# pasar : pasar
# pppls : pppls
# mengibur : mengibur
# ayang : ayang
# munkin : munkin
# inj : inj
# platinum : platinum
# rising : rising
# hero : hero
# berjalannn : berjalannn
# disneyyy : disneyyy
# sendback : sendback
# pernh : pernh
# dowld : dowld
# aktf : aktf
# apakh : apakh
# akuny : akuny
# kodi : kodi
# capture : capture
# marketing : marketing
# short : short
# scifi : scifi
# adventure : adventure
# weekly : weekly
# lebh : lebh
# untg : untg
# asih : asih
# bufring : bufring
# fl : fl
# ciri : ciri
# khas : khas
# koc : koc
# aktivasinya : aktivasinya
# sellau : sellau
# doraemon : doraemon
# bang : bang
# sync : sync
# fidio : fidio
# peebaiki : peebaiki
# shake : shake
# koreanya : koreanya
# diney : diney
# drakornya : drakornya
# firtur : firtur
# poster : poster
# useless : useless
# wwe : wwe
# jadwal : jadwal
# wrestlemania : wrestlemania
# alternatif : alternatif
# customize : customize
# sinkron : sinkron
# riles : riles
# langsur : langsur
# diplosok : diplosok
# landskap : landskap
# horizontal : horizontal
# plasenta : plasenta
# mengirimi : kirim
# verfikasi : verfikasi
# because : because
# surprisingly : surprisingly
# matang : matang
# moreover : moreover
# nyabut : nyabut
# southeast : southeast
# want : want
# lose : lose
# your : your
# better : better
# rid : rid
# problems : problems
# asap : asap
# kelompok : kelompok
# hbo : hbo
# apv : apv
# aplikasunya : aplikasunya
# kedetec : kedetec
# bahaya : bahaya
# bangeeeeeett : bangeeeeeett
# cermin : cermin
# dirinci : dirinci
# perinci : perinci
# dev : dev
# keyword : keyword
# vampire : vampire
# vampir : vampir
# scriptnya : scriptnya
# navigasi : navigasi
# seperri : seperri
# pitur : pitur
# tahuanan : tahuanan
# boys : boys
# consent : consent
# errorconst : errorconst
# fikir : fikir
# nonoton : nonoton
# teryata : teryata
# bamget : bamget
# apaansih : apaansih
# dihape : dihape
# mengupdate : mengupdate
# telkomnyet : telkomnyet
# work : work
# mediatek : mediatek
# dw : dw
# reverse : reverse
# mundurin : mundurin
# kb : kb
# tteo : tteo
# iqiyi : iqiyi
# okey : okey
# ikon : ikon
# bberapa : bberapa
# ngedownload : ngedownload
# ngertinya : ngertinya
# nntonnya : nntonnya
# switched : switched
# birth : birth
# bunk : bunk
# urus : urus
# double : double
# tap : tap
# dtk : dtk
# viwer : viwer
# dimasukin : dimasukin
# viwe : viwe
# konsumsi : konsumsi
# eposide : eposide
# nanggung : nanggung
# rembet : rembet
# blurry : blurry
# tambak : tambak
# subtile : subtile
# dengerinnya : dengerinnya
# latih : latih
# yutup : yutup
# mirorin : mirorin
# edukasi : edukasi
# national : national
# geografi : geografi
# gadang : gadang
# ejen : ejen
# ali : ali
# band : band
# final : final
# kadaluarsanya : kadaluarsanya
# password : password
# baffer : baffer
# ayok : ayok
# romans : romans
# masalahny : masalahny
# miring : miring
# layarny : layarny
# kecilin : kecilin
# bayang : bayang
# menang : menang
# nominasi : nominasi
# academy : academy
# awards : awards
# days : days
# diwifinya : diwifinya
# luang : luang
# ngeupdate : ngeupdate
# nettflix : nettflix
# thank : thank
# ux : ux
# dab : dab
# mundur : mundur
# kucian : kucian
# gawai : gawai
# lamaaaaaa : lamaaaaaa
# micro : micro
# hollywoodnya : hollywoodnya
# depa : depa
# riwayat : riwayat
# pandemi : pandemi
# rilex : rilex
# sepakat : sepakat
# sinema : sinema
# vokal : vokal
# efektif : efektif
# sound : sound
# controlnya : controlnya
# otomotis : otomotis
# nggak : nggak
# agam : agam
# cantum : cantum
# webdisney : webdisney
# nyetel : nyetel
# singkron : singkron
# sudaj : sudaj
# dibypass : dibypass
# kritik : kritik
# bagusssssss : bagusssssss
# keliaatan : keliaatan
# moho : moho
# nyangkut : nyangkut
# dubber : dubber
# sori : sori
# alat : alat
# ultra : ultra
# bix : bix
# petunjuknyaa : petunjuknyaa
# save : save
# syuting : syuting
# hitunganya : hitunganya
# nontonn : nontonn
# vidionya : vidionya
# gmbrnya : gmbrnya
# greget : greget
# pendek : pendek
# ve : ve
# linked : linked
# with : with
# number : number
# before : before
# boross : boross
# vsia : vsia
# dibantuu : dibantuu
# mhn : mhn
# ditmbhkan : ditmbhkan
# sgr : sgr
# sinopsis : sinopsis
# mgkn : mgkn
# pending : pending
# harusnyaaaa : harusnyaaaa
# kaau : kaau
# lebig : lebig
# ketat : ketat
# kasihan : kasihan
# diam : diam
# pencil : pencil
# fasilitas : fasilitas
# gedein : gedein
# hobi : hobi
# perbanya : perbanya
# mcu : mcu
# power : power
# ranger : ranger
# gemar : gemar
# produksi : produksi
# ninja : ninja
# storm : storm
# rpm : rpm
# blnnya : blnnya
# register : register
# menoonton : menoonton
# rua : rua
# penguna : penguna
# philips : philips
# tara : tara
# yanh : yanh
# consumer : consumer
# keteranhan : keteranhan
# mahir : mahir
# wawas : wawas
# entertainment : entertainment
# smntra : smntra
# maxstrem : maxstrem
# pintar : pintar
# telanjur : telanjur
# perna : perna
# anggap : anggap
# hello : hello
# indian : indian
# ludes : ludes
# pindahin : pindahin
# membershipnya : membershipnya
# donlwod : donlwod
# xx : xx
# sangchi : sangchi
# malalui : malalui
# ewalet : ewalet
# padaha : padaha
# drekomend : drekomend
# walet : walet
# individu : individu
# frozen : frozen
# anmb : anmb
# qualitasnya : qualitasnya
# automatis : automatis
# nyerap : nyerap
# stack : stack
# maintenance : maintenance
# sarananin : sarananin
# fleksibel : fleksibel
# cempreng : cempreng
# vudeo : vudeo
# poading : poading
# smntara : smntara
# stasiun : stasiun
# antv : antv
# diantv : diantv
# scenenya : scenenya
# hatstar : hatstar
# engah : engah
# spoiler : spoiler
# thumbnail : thumbnail
# synopsis : synopsis
# maaih : maaih
# maklum : maklum
# moohon : moohon
# lainn : lainn
# dinikmatin : dinikmatin
# scree : scree
# fokus : fokus
# respect : respect
# akuisisi : akuisisi
# ikonik : ikonik
# very : very
# disappointing : disappointing
# sorting : sorting
# month : month
# year : year
# angga : angga
# nguras : nguras
# swperti : swperti
# giqi : giqi
# ayah : ayah
# ngeklik : ngeklik
# arahin : arahin
# benaran : benar
# sempurna : sempurna
# justice : justice
# league : league
# campur : campur
# lapak : lapak
# sedangkn : sedangkn
# sendrii : sendrii
# blan : blan
# dpan : dpan
# bertmbah : bertmbah
# officenya : officenya
# detail : detail
# doankk : doankk
# annya : annya
# folder : folder
# sepet : sepet
# nepliks : nepliks
# suksens : suksens
# verifynya : verifynya
# mgk : mgk
# sayangngga : sayangngga
# smpan : smpan
# mnyebalkan : mnyebalkan
# plislah : plislah
# ngeluh : ngeluh
# xxi : xxi
# golong : golong
# miskin : miskin
# trialnya : trialnya
# dropp : dropp
# diinstal : diinstal
# melalj : melalj
# proksi : proksi
# renti : renti
# learn : learn
# from : from
# another : another
# competitor : competitor
# captain : captain
# america : america
# seasons : seasons
# secrets : secrets
# sulphur : sulphur
# springs : springs
# hi : hi
# krishn : krishn
# epsnya : epsnya
# kasihh : kasihh
# huhu : huhu
# instastory : instastory
# aksen : aksen
# miskomunikasi : miskomunikasi
# gajak : gajak
# bangkrutt : bangkrutt
# embat : embat
# puya : puya
# jirrrrrrr : jirrrrrrr
# noyon : noyon
# bagussssssssss : bagussssssssss
# toton : toton
# adk : adk
# ver : ver
# laki : laki
# wanita : wanita
# perpenjang : perpenjang
# convenience : convenience
# stores : stores
# sytd : sytd
# layananannya : layananannya
# lagibada : lagibada
# geo : geo
# samsek : samsek
# perkara : perkara
# movienya : movienya
# fillmnya : fillmnya
# shope : shope
# webnya : webnya
# nys : nys
# tam : tam
# doung : doung
# transformers : transformers
# tengok : tengok
# agen : agen
# musim : musim
# seeehhh : seeehhh
# malem : malem
# sono : sono
# sewa : sewa
# jum : jum
# bisik : bisik
# gelora : gelora
# venom : venom
# be : be
# carnage : carnage
# transformer : transformer
# buff : buff
# bis : bis
# membesarkan : besar
# anatomi : anatomi
# epd : epd
# big : big
# toy : toy
# zootopia : zootopia
# bolt : bolt
# dinosaur : dinosaur
# lion : lion
# king : king
# remaja : remaja
# gtau : gtau
# kuantitas : kuantitas
# bendahara : bendahara
# googledongle : googledongle
# tatap : tatap
# bas : bas
# sibe : sibe
# groupwatch : groupwatch
# ndan : ndan
# perhatikan : perhati
# keyamanan : keyamanan
# beauty : beauty
# beast : beast
# iconet : iconet
# kitu : kitu
# disnay : disnay
# compatible : compatible
# holstar : holstar
# completed : completed
# review : review
# leta : leta
# jarak : jarak
# sdngkan : sdngkan
# languenge : languenge
# tpai : tpai
# transfers : transfers
# exaitide : exaitide
# dluan : dluan
# semoga : moga
# kadalursa : kadalursa
# yag : yag
# pakw : pakw
# planet : planet
# films : films
# inside : inside
# much : much
# ganguan : ganguan
# developor : developor
# desney : desney
# soalx : soalx
# curhat : curhat
# innya : innya
# led : led
# brhenti : brhenti
# direstrat : direstrat
# mextrim : mextrim
# msxtremmnya : msxtremmnya
# egk : egk
# maxtrimnya : maxtrimnya
# hits : hits
# filmmya : filmmya
# rons : rons
# gones : gones
# hotel : hotel
# transyvania : transyvania
# rom : rom
# sim : sim
# asix : asix
# flem : flem
# tarif : tarif
# filmny : filmny
# prefer : prefer
# taroh : taroh
# adaptasi : adaptasi
# ketemu : ketemu
# layana : layana
# knpaa : knpaa
# group : group
# doble : doble
# huuhhhh : huuhhhh
# masya : masya
# harua : harua
# done : done
# february : february
# sekolah : sekolah
# corona : corona
# nasib : nasib
# apalagimusimcorona : apalagimusimcorona
# jelang : jelang
# orbit : orbit
# kayar : kayar
# giring : giring
# sepenuh : sepenuh
# ngeleg : ngeleg
# irit : irit
# uh : uh
# maksudnya : maksud
# bermasaah : bermasaah
# nontkn : nontkn
# usap : usap
# auditor : auditor
# mic : mic
# ko : ko
# xtreme : xtreme
# kenapaaaa : kenapaaaa
# kenawhy : kenawhy
# didisney : didisney
# cromecast : cromecast
# kategori : kategori
# radak : radak
# serie : serie
# malesin : malesin
# rookie : rookie
# corp : corp
# analog : analog
# nyaring : nyaring
# realse : realse
# goggle : goggle
# jaman : jaman
# dulunya : dulunya
# aplikadi : aplikadi
# joss : joss
# girl : girl
# kangen : kangen
# hoox : hoox
# dtonton : dtonton
# perbnyak : perbnyak
# neflik : neflik
# sjenis : sjenis
# komedi : komedi
# tambahn : tambahn
# dangal : dangal
# laris : laris
# cekket : cekket
# bh : bh
# sharpening : sharpening
# develover : develover
# canelnya : canelnya
# gaka : gaka
# vr : vr
# reality : reality
# raw : raw
# lanskap : lanskap
# googleplay : googleplay
# magsudnya : magsudnya
# minnnn : minnnn
# kmbl : kmbl
# biokop : biokop
# downloud : downloud
# indihe : indihe
# walapun : walapun
# pucat : pucat
# teknis : teknis
# cat : cat
# noir : noir
# apks : apks
# jawabanya : jawabanya
# reta : reta
# ginjal : ginjal
# kelen : kelen
# mendisable : mendisable
# sensitif : sensitif
# fim : fim
# ...
# heu : heu
# alangka : alangka
# hargnya : hargnya
# yuk : yuk
# dftar : dftar
# aaaaa : aaaaa
# sennengg : sennengg
# cuss : cuss
# yesss : yesss
# mntap : mntap
# donghua : donghua
# banya : banya
# xixixi : xixixi
# violet : violet
# evergarden : evergarden
# vivy : vivy
# fluorite : fluorite
# eye : eye
# song : song
# mengiginkan : mengiginkan
# disiarin : disiarin
# eksperesi : eksperesi
# suat : suat
# afla : afla
# cops : cops
# kang : kang
# daniel : daniel
# edisi : edisi
# marverl : marverl
# ngebuat : ngebuat
# wortit : wortit
# zaman : zaman
# klub : klub
# solo : solo
# tetoos : tetoos
# anying : anying
# boboboy : boboboy
# peaky : peaky
# blinders : blinders
# suadah : suadah
# experiencenya : experiencenya
# biggest : biggest
# farm : farm
# buatkan : buat
# documenter : documenter
# estate : estate
# guru : guru
# iku : iku
# klasik : klasik
# anteng : anteng
# sahabat : sahabat
# cuy : cuy
# muluuuuuuuu : muluuuuuuuu
# ishh : ishh
# bgst : bgst
# hambat : hambat
# brother : brother
# pacific : pacific
# afiliasi : afiliasi
# job : job
# casting : casting
# wujud : wujud
# androidtv : androidtv
# release : release
# nyatu : nyatu
# menyangka : sangka
# bleach : bleach
# piece : piece
# lyoko : lyoko
# white : white
# collar : collar
# ngepause : ngepause
# kapause : kapause
# sekarnag : sekarnag
# studios : studios
# holand : holand
# meperbaikinnya : meperbaikinnya
# menginstall : menginstall
# layak : layak
# banyaaak : banyaaak
# tol : tol
# motor : motor
# bangus : bangus
# uodate : uodate
# awesome : awesome
# portrait : portrait
# kontra : kontra
# nuansa : nuansa
# semonga : semonga
# karenan : karenan
# penganturan : penganturan
# island : island
# artikel : artikel
# uk : uk
# feb : feb
# downrate : downrate
# panik : panik
# erroe : erroe
# doll : doll
# sabrina : sabrina
# padu : padu
# bayarnyaaaaaaaa : bayarnyaaaaaaaa
# kolaborasi : kolaborasi
# nickelodion : nickelodion
# always : always
# mantapppp : mantapppp
# jgaaa : jgaaa
# animation : animation
# ngangngengngong : ngangngengngong
# kaum : kaum
# dang : dang
# thetering : thetering
# indoesia : indoesia
# ditampilin : ditampilin
# streamming : streamming
# publishernya : publishernya
# tglnya : tglnya
# diberentiin : diberentiin
# naati : naati
# mind : mind
# ppv : ppv
# royal : royal
# rumble : rumble
# mantaap : mantaap
# nemamin : nemamin
# motivasi : motivasi
# fantasi : fantasi
# nyesuain : nyesuain
# terbaikk : terbaikk
# intenfacenya : intenfacenya
# langganannnya : langganannnya
# hadiah : hadiah
# amazing : amazing
# over : over
# platfrom : platfrom
# bahagia : bahagia
# jugaaa : jugaaa
# dipindahin : dipindahin
# termantabek : termantabek
# banyakkkk : banyakkkk
# rotasi : rotasi
# hya : hya
# demand : demand
# berlanggananx : berlanggananx
# penawran : penawran
# bufer : bufer
# spesifikasi : spesifikasi
# mencak : mencak
# slebew : slebew
# anti : anti
# kos : kos
# anggur : anggur
# surround : surround
# unggul : unggul
# spen : spen
# ehhhh : ehhhh
# masterpiece : masterpiece
# shawshank : shawshank
# gassss : gassss
# simerah : simerah
# teliti : teliti
# miui : miui
# custom : custom
# nambahin : nambahin
# gapake : gapake
# chek : chek
# preman : preman
# pensiun : pensiun
# genggam : genggam
# goodjob : goodjob
# zombies : zombies
# trialkan : trialkan
# trialan : trialan
# murahh : murahh
# partner : partner
# kumpul : kumpul
# hit : hit
# tvmu : tvmu
# androidmu : androidmu
# januari : januari
# till : till
# tokoh : tokoh
# ranting : ranting
# sok : sok
# geratisan : geratisan
# salahsatunya : salahsatunya
# putri : putri
# dlunya : dlunya
# boy : boy
# meets : meets
# ilah : ilah
# sniper : sniper
# sen : sen
# ghibli : ghibli
# ehehem : ehehem
# yak : yak
# software : software
# lord : lord
# rings : rings
# hobbit : hobbit
# bokep : bokep
# trmks : trmks
# komenin : komenin
# mar : mar
# trimss : trimss
# wihhhh : wihhhh
# otaku : otaku
# gwej : gwej
# dokter : dokter
# strenge : strenge
# idam : idam
# nyabgya : nyabgya
# ehe : ehe
# developernyaa : developernyaa
# into : into
# uknown : uknown
# mimpi : mimpi
# anna : anna
# sihir : sihir
# es : es
# jendela : jendela
# arendel : arendel
# luvv : luvv
# multibahasa : multibahasa
# losmen : losmen
# bu : bu
# broto : broto
# adit : adit
# sopo : sopo
# jarwo : jarwo
# ngadain : ngadain
# dubling : dubling
# posting : posting
# devices : devices
# rupiah : rupiah
# uwu : uwu
# tahap : tahap
# jeli : jeli
# negatif : negatif
# masukkin : masukkin
# ngegas : ngegas
# otak : otak
# maluin : maluin
# itung : itung
# kismin : kismin
# assembled : assembled
# manja : manja
# jago : jago
# hasut : hasut
# starwars : starwars
# ongoing : ongoing
# ceruta : ceruta
# crime : crime
# investigasi : investigasi
# yeayy : yeayy
# kopid : kopid
# duid : duid
# elegan : elegan
# kntl : kntl
# bring : bring
# segmen : segmen
# wiro : wiro
# sableng : sableng
# john : john
# constantine : constantine
# west : west
# dsmber : dsmber
# seterusnyaa : seterusnyaa
# menghemaf : menghemaf
# covid : covid
# premiere : premiere
# wdas : wdas
# ng : ng
# titanic : titanic
# giur : giur
# rio : rio
# opening : opening
# nurun : nurun
# mickey : mickey
# epsd : epsd
# closed : closed
# ngebantu : ngebantu
# human : human
# ldr : ldr
# klobdi : klobdi
# pinjam : pinjam
# numpang : numpang
# awkakakakaka : awkakakakaka
# goblo : goblo
# menyalahkan : salah
# jelekbangetttttttttttttttttttt : jelekbangetttttttttttttttttttt
# papalepapalepapalepaleee : papalepapalepapalepaleee
# bagaus : bagaus
# donglod : donglod
# jadipulsa : jadipulsa
# cepetan : cepetan
# strain : strain
# riah : riah
# tysm : tysm
# hostars : hostars
# booming : booming
# sebulum : sebulum
# horstar : horstar
# langkapin : langkapin
# ngaka : ngaka
# ow : ow
# hasilny : hasilny
# sptnya : sptnya
# sy : sy
# pilihanya : pilihanya
# lisensi : lisensi
# suuuuuuuu : suuuuuuuu
# dbayar : dbayar
# dsini : dsini
# belai : belai
# lirik : lirik
# istri : istri
# gais : gais
# bruckheimer : bruckheimer
# kaleng : kaleng
# memanjakan : manja
# telinga : telinga
# jagoanya : jagoanya
# thaks : thaks
# nagih : nagih
# trmkasih : trmkasih
# trimkasih : trimkasih
# gakapa : gakapa
# thxx : thxx
# mouon : mouon
# marver : marver
# yth : yth
# antek : antek
# marked : marked
# death : death
# kill : kill
# agal : agal
# crow : crow
# kuali : kuali
# gaks : gaks
# ering : ering
# kenyam : kenyam
# terup : terup
# bayarin : bayarin
# tante : tante
# tayangnyaa : tayangnyaa
# hina : hina
# mensupport : mensupport
# cringe : cringe
# ratingnya : ratingnya
# grapik : grapik
# paltform : paltform
# lpgin : lpgin
# toop : toop
# kim : kim
# tp : tp
# dor : dor
# dorrr : dorrr
# ringkas : ringkas
# grade : grade
# canda : canda
# developr : developr
# trek : trek
# pikirin : pikirin
# lancarr : lancarr
# sekalli : sekalli
# limpah : limpah
# raja : raja
# arena : arena
# strategi : strategi
# gandeng : gandeng
# dann : dann
# udaj : udaj
# didengernya : didengernya
# aplikasinyaa : aplikasinyaa
# ngerekomendasiin : ngerekomendasiin
# terrrrimakasihh : terrrrimakasihh
# asdfghhjkklllkdhudjdjodnlposbdjpsp : asdfghhjkklllkdhudjdjodnlposbdjpsp
# darkwing : darkwing
# kaki : kaki
# baguz : baguz
# bangetz : bangetz
# keran : keran
# bangettz : bangettz
# nongkrong : nongkrong
# nemenin : nemenin
# jhoda : jhoda
# salim : salim
# anarkali : anarkali
# extended : extended
# aktris : aktris
# bagasanya : bagasanya
# jug : jug
# homeland : homeland
# sabanyak : sabanyak
# anaknya : anak
# telak : telak
# cimb : cimb
# niaga : niaga
# merchant : merchant
# case : case
# aktifkanx : aktifkanx
# mengakitkan : mengakitkan
# uwaw : uwaw
# mungkinn : mungkinn
# karna : karna
# sarana : sarana
# graphic : graphic
# avanger : avanger
# byeeee : byeeee
# eropa : eropa
# lagg : lagg
# abiss : abiss
# lagggg : lagggg
# konslet : konslet
# smpah : smpah
# heroes : heroes
# buy : buy
# alit : alit
# cumak : cumak
# krg : krg
# ngusir : ngusir
# duduk : duduk
# manis : manis
# okeeeeeeeeee : okeeeeeeeeee
# bangeeeeeeettttttt : bangeeeeeeettttttt
# bisokop : bisokop
# hotstrar : hotstrar
# begroun : begroun
# baguus : baguus
# diwebsite : diwebsite
# ffh : ffh
# imperfect : imperfect
# youu : youu
# claim : claim
# pictures : pictures
# andrew : andrew
# garfield : garfield
# tobey : tobey
# maguiere : maguiere
# jarlet : jarlet
# scoobiedobiedoo : scoobiedobiedoo
# kerjasam : kerjasam
# geografik : geografik
# bts : bts
# sayngnya : sayngnya
# sukaaaaaaaa : sukaaaaaaaa
# tangled : tangled
# nemo : nemo
# wreck : wreck
# ralph : ralph
# ulusan : ulusan
# later : later
# sebelumx : sebelumx
# filmx : filmx
# utak : utak
# pokokx : pokokx
# sayaharap : sayaharap
# terbit : terbit
# poting : poting
# negrinya : negrinya
# showw : showw
# suluh : suluh
# padalahal : padalahal
# pakeknya : pakeknya
# recommend : recommend
# smoga : smoga
# sedanglan : sedanglan
# advanced : advanced
# undur : undur
# nasional : nasional
# kenang : kenang
# princess : princess
# beban : beban
# shared : shared
# gratisin : gratisin
# gwe : gwe
# syukur : syukur
# wkwkw : wkwkw
# artis : artis
# sekira : sekira
# jaditolong : jaditolong
# awas : awas
# jak : jak
# endgame : endgame
# mutiara : mutiara
# blablabla : blablabla
# seruuuu : seruuuu
# parahhhh : parahhhh
# ketigalan : ketigalan
# multiverse : multiverse
# wkwkwkwkwkwk : wkwkwkwkwkwk
# aplilasi : aplilasi
# selanjutbya : selanjutbya
# pesimis : pesimis
# gilaaaaa : gilaaaaa
# dep : dep
# luca : luca
# spidey : spidey
# friends : friends
# fiture : fiture
# kaloboleh : kaloboleh
# usul : usul
# iseng : iseng
# smackdownya : smackdownya
# dibuatin : dibuatin
# storyline : storyline
# nxtnya : nxtnya
# trmksh : trmksh
# pame : pame
# nggsk : nggsk
# morty : morty
# mantengin : mantengin
# tron : tron
# uprising : uprising
# bacot : bacot
# muka : muka
# bumi : bumi
# lem : lem
# documentary : documentary
# fiksi : fiksi
# drma : drma
# iblis : iblis
# jemput : jemput
# ayat : ayat
# aladdin : aladdin
# deer : deer
# couldron : couldron
# sampean : sampean
# dolowad : dolowad
# filtur : filtur
# iloveyou : iloveyou
# gw : gw
# filmmmm : filmmmm
# publish : publish
# tersedi : tersedi
# ssaran : ssaran
# supya : supya
# memberitahu : memberitahu
# marcel : marcel
# maha : maha
# makany : makany
# interne : interne
# az : az
# markotop : markotop
# endul : endul
# surendul : surendul
# kendul : kendul
# rofunzel : rofunzel
# dira : dira
# fp : fp
# dichannel : dichannel
# gift : gift
# away : away
# suabcribe : suabcribe
# dilike : dilike
# coment : coment
# pengunguman : pengunguman
# robbal : robbal
# alaminn : alaminn
# doa : doa
# guiiiiis : guiiiiis
# wr : wr
# wb : wb
# mantaaappp : mantaaappp
# bett : bett
# flix : flix
# epl : epl
# mola : mola
# champion : champion
# heuheu : heuheu
# diselipin : diselipin
# berani : berani
# sekeluaraga : sekeluaraga
# nyapuas : nyapuas
# laib : laib
# axis : axis
# interstellar : interstellar
# sabel : sabel
# coz : coz
# shinchan : shinchan
# spongebob : spongebob
# mamang : mamang
# mando : mando
# finish : finish
# saksi : saksi
# pintu : pintu
# kereeeennn : kereeeennn
# samart : samart
# memnag : memnag
# entek : entek
# ngeluhin : ngeluhin
# landa : landa
# newcomer : newcomer
# dabling : dabling
# subtitlle : subtitlle
# siii : siii
# graffity : graffity
# pokonyaa : pokonyaa
# kalap : kalap
# definisi : definisi
# tenang : tenang
# syuka : syuka
# fals : fals
# kingdom : kingdom
# actornya : actornya
# frank : frank
# grillo : grillo
# hooq : hooq
# industri : industri
# dusney : dusney
# dewas : dewas
# princesnya : princesnya
# vibe : vibe
# pol : pol
# kesitu : kesitu
# keinget : keinget
# wajibbb : wajibbb
# gaissss : gaissss
# frome : frome
# jungle : jungle
# junction : junction
# behh : behh
# subhanallah : subhanallah
# firts : firts
# incridible : incridible
# legion : legion
# noice : noice
# slngkapnya : slngkapnya
# mistery : mistery
# triller : triller
# psyko : psyko
# dllll : dllll
# detective : detective
# conan : conan
# filosofi : filosofi
# digoogle : digoogle
# mainstream : mainstream
# ralat : ralat
# apliksinya : apliksinya
# diplaystor : diplaystor
# dimaapkan : dimaapkan
# notice : notice
# god : god
# puass : puass
# ciamik : ciamik
# kamar : kamar
# alifiopm : alifiopm
# dadah : dadah
# screennya : screennya
# dapag : dapag
# semu : semu
# andalin : andalin
# snsor : snsor
# xvideos : xvideos
# wizards : wizards
# waverly : waverly
# khusunya : khusunya
# gamenya : gamenya
# hehhehe : hehhehe
# buoy : buoy
# izan : izan
# {'halo': 'halo', 'kak': 'kak', 'mengasih': 'asih', 'masuk': 'masuk', 'timbang': 'timbang', 'atur': 'atur', 'ukur': 'ukur', 'font': 'font', 'subtitlenya': 'subtitlenya', 'kadang': 'kadang', 'film': 'film', 'pengaruh': 'pengaruh', 'jaring': 'jaring', 'upgrade': 'upgrade', 'menonton': 'tonton', 'series': 'series', 'movie': 'movie', 'episode': 'episode', 'trjadi': 'trjadi', 'error': 'error', 'gambar': 'gambar', 'jalan': 'jalan', 'suara': 'suara', 'jengkel': 'jengkel', 'konten': 'konten', 'download': 'download', 'putar': 'putar', 'hubungi': 'hubung', 'admin': 'admin', 'disney': 'disney', 'kendala': 'kendala', 'pas': 'pas', 'hapus': 'hapus', 'coba': 'coba', 'streaming': 'streaming', 'pakai': 'pakai', 'fungsi': 'fungsi', 'sorry': 'sorry', 'kualitas': 'kualitas', 'video': 'video', 'mas': 'mas', 'buram': 'buram', 'hd': 'hd', 'jelek': 'jelek', 'rendah': 'rendah', 'contoh': 'contoh', 'setel': 'setel', 'the': 'the', 'incredibles': 'incredibles', 'mohon': 'mohon', 'cepat': 'cepat', 'bug': 'bug', 'nyaman': 'nyaman', 'cache': 'cache', 'data': 'data', 'terimakasih': 'terimakasih', 'ganti': 'ganti', 'resolusi': 'resolusi', 'layar': 'layar', 'hitam': 'hitam', 'uninstall': 'uninstall', 'normal': 'normal', 'tolong': 'tolong', 'fix': 'fix', 'tonton': 'tonton', 'parah': 'parah', 'aplikasi': 'aplikasi', 'rusak': 'rusak', 'install': 'install', 'rencana': 'rencana', 'lokal': 'lokal', 'tayang': 'tayang', 'sistem': 'sistem', 'langgan': 'langgan', 'harap': 'harap', 'bayar': 'bayar', 'minimarket': 'minimarket', 'alfa': 'alfa', 'indomaret': 'indomaret', 'mudah': 'mudah', 'banget': 'banget', 'sekian': 'sekian', 'update': 'update', 'bugnya': 'bugnya', 'terkadang': 'terkadang', 'merespon': 'merespon', 'gelap': 'gelap', 'ubah': 'ubah', 'teks': 'teks', 'subtitle': 'subtitle', 'baca': 'baca', 'fitur': 'fitur', 'ting': 'ting', 'lho': 'lho', 'orang': 'orang', 'bundle': 'bundle', 'hulu': 'hulu', 'skip': 'skip', 'ane': 'ane', 'india': 'india', 'bos': 'bos', 'ku': 'ku', 'iya': 'iya', 'wajib': 'wajib', 'daftar': 'daftar', 'susah': 'susah', 'transfer': 'transfer', 'bank': 'bank', 'ewallet': 'ewallet', 'mesti': 'mesti', 'credit': 'credit', 'card': 'card', 'kayak': 'kayak', 'nama': 'nama', 'mao': 'mao', 'mencoba': 'coba', 'cocok': 'cocok', 'menyesal': 'sesal', 'gbsa': 'gbsa', 'stak': 'stak', 'hp': 'hp', 'reset': 'reset', 'cek': 'cek', 'pilih': 'pilih', 'muncul': 'muncul', 'langsung': 'langsung', 'restart': 'restart', 'ulang': 'ulang', 'kali': 'kali', 'pikir': 'pikir', 'deh': 'deh', 'jujur': 'jujur', 'alami': 'alami', 'langgang': 'langgang', 'member': 'member', 'hotstar': 'hotstar', 'menontonnya': 'tonton', 'aman': 'aman', 'ios': 'ios', 'diplay': 'diplay', 'play': 'play', 'hang': 'hang', 'restar': 'restar', 'sdah': 'sdah', 'uninstal': 'uninstal', 'kembang': 'kembang', 'laku': 'laku', 'kompatibel': 'kompatibel', 'samsung': 'samsung', 'login': 'login', 'kode': 'kode', 'otp': 'otp', 'bagus': 'bagus', 'gin': 'gin', 'buruk': 'buruk', 'offline': 'offline', 'loading': 'loading', 'macet': 'macet', 'sesuai': 'sesuai', 'didownload': 'didownload', 'muas': 'muas', 'low': 'low', 'setting': 'setting', 'ribet': 'ribet', 'mode': 'mode', 'tansfer': 'tansfer', 'dana': 'dana', 'doku': 'doku', 'registrasi': 'registrasi', 'kartu': 'kartu', 'kredit': 'kredit', 'debit': 'debit', 'gopay': 'gopay', 'gopaynya': 'gopaynya', 'reistrasi': 'reistrasi', 'niat': 'niat', 'maksa': 'maksa', 'ahirnya': 'ahirnya', 'netflix': 'netflix', 'gua': 'gua', 'lot': 'lot', 'log': 'log', 'sms': 'sms', 'via': 'via', 'call': 'call', 'henti': 'henti', 'bayarny': 'bayarny', 'krtu': 'krtu', 'puny': 'puny', 'potong': 'potong', 'pulsa': 'pulsa', 'byarny': 'byarny', 'dc': 'dc', 'iklan': 'iklan', 'bohong': 'bohong', 'tv': 'tv', 'support': 'support', 'telp': 'telp', 'indihome': 'indihome', 'stb': 'stb', 'dukung': 'dukung', 'sila': 'sila', 'or': 'or', 'laptop': 'laptop', 'simple': 'simple', 'gampang': 'gampang', 'tunggu': 'tunggu', 'payah': 'payah', 'batalin': 'batalin', 'maksimal': 'maksimal', 'batas': 'batas', 'unduh': 'unduh', ...
# ------------------------
# Pandas Apply:   0%|          | 0/6000 [00:00<?, ?it/s]
# 0       [halo, kak, asih, masuk, timbang, atur, ukur, ...
# 1       [konten, download, putar, hubung, admin, disne...
# 2       [sorry, kualitas, video, atur, mas, buram, hd,...
# 3       [ganti, resolusi, layar, hitam, film, mas, uni...
# 4       [install, aplikasi, rencana, tonton, series, l...
#                               ...
# 5995    [gamenya, bagus, eh, maksud, aplikasi, hehhehe...
# 5996    [wanda, vision, episode, terima, kasih, disney...
# 5997    [bagus, banget, aplikasi, puas, pakai, lagu, h...
# 5998    [saran, login, kode, notifikasi, coba, loginny...
# 5999    [terimakasih, disney, telkomsel, good, job, to...
# Name: review_text_tokens_stemmed, Length: 6000, dtype: object

# %%
normalizad_word = pd.read_csv("/content/drive/MyDrive/codeskripsi/kamus_alay_syarah.csv")

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

Scrapped_Data['review_text_normalized'] = Scrapped_Data['review_text_tokens_stemmed'].apply(normalized_term)

Scrapped_Data['review_text_normalized'].head(10)
# Out:
# 0    [halo, kak, asih, masuk, timbang, atur, ukur, ...
# 1    [konten, download, putar, hubung, admin, disne...
# 2    [sorry, kualitas, video, atur, mas, buram, hd,...
# 3    [ganti, resolusi, layar, hitam, film, mas, uni...
# 4    [install, aplikasi, rencana, tonton, series, l...
# 5    [aplikasi, update, bugnya, terkadang, merespon...
# 6    [teks, subtitle, baca, mohon, subtitle, fitur,...
# 7    [masuk, disney, masuk, disney, bundle, hulu, s...
# 8    [langgan, bayar, pakai, transfer, bank, indoma...
# 9    [sesal, langgan, gbsa, tonton, film, stuck, ga...
# Name: review_text_normalized, dtype: object

# %%
Scrapped_Data["review_text_normalizedjoin"] = [' '.join(word) for word in Scrapped_Data["review_text_normalized"]]

# %%
# Memuat data positif dan negatif leksikon
file_read_p = pd.read_csv("/content/InSet/positive.tsv", sep='\t')
lexicon_positive = file_read_p.set_index('word').to_dict()['weight']

file_read_n = pd.read_csv("/content/InSet/negative.tsv", sep='\t')
lexicon_negative = file_read_n.set_index('word').to_dict()['weight']

# %%
# Fungsi untuk menentukan polaritas sentimen 
def sentiment_analysis_lexicon_indonesia(text):
    #for word in text:
    score = 0
    for word in text:
        if (word in lexicon_positive):
            score = score + lexicon_positive[word]
    for word in text:
        if (word in lexicon_negative):
            score = score + lexicon_negative[word]
    polarity=''
    if (score > 0):
        polarity = 'positive'
    elif (score < 0):
        polarity = 'negative'
    else:
        polarity = 'neutral'
    return score, polarity

results = Scrapped_Data['review_text_normalized'].apply(sentiment_analysis_lexicon_indonesia)
results = list(zip(*results))
Scrapped_Data['polarity_score'] = results[0]
Scrapped_Data['polarity'] = results[1]
print(Scrapped_Data['polarity'].value_counts())
# Scrapped_Data.to_csv("/content/drive/MyDrive/Colab Notebooks/PREPRO6Kfinal_data.csv")
# Out:
# negative    3705
# positive    1655
# neutral      640
# Name: polarity, dtype: int64

# %%
Scrapped_Data.to_csv("filbert.csv",sep='\t', header=None, index=False)
#donwload trs dipake join sm polarity

# %%
def make_corpus(column):
    
    corpus_list = []

    for text in column:
        cleaned_list = text.split(' ')
        corpus_list.extend(cleaned_list)     
        
    # transform list of words into 1 body of text
    corpus = ' '.join(corpus_list)
    corpus = re.sub('[ ]+',' ',corpus) # replace double whitespace with one
        
    return corpus

# %%
# Takes a while
corpus = make_corpus(df.review_text)

# %%
# counting unique words
corpus_set = set(corpus.split(' '))

print(f'Count of unique words in corpus: {len(corpus_set)}')
# Out:
# Count of unique words in corpus: 6018

# %%
# function for freqdist
def word_freq(corpus, top=5):
    tokenized_word = word_tokenize(corpus)
    freqdist = FreqDist(tokenized_word)
    freqdist = freqdist.most_common(top) # list of tuples 
    
    # decompose into label and frequency
    label = [tup[0] for tup in freqdist]
    freq = [tup[1] for tup in freqdist]
    df = pd.DataFrame({'word':label, 'freq':freq})
    
    return df

# %%
corpus_freq = word_freq(corpus, top=20)

# %%
# Config params
plt.style.use('default')
sns.set(style='ticks', palette='Set2')
mpl.rcParams['axes.titlesize'] = 20
mpl.rcParams['axes.titlepad'] = 20

# Compare plots of train and test corpus
f, ax1 = plt.subplots(1,figsize=(15,5))

sns.barplot(x='word', y='freq', data=corpus_freq, ax=ax1)
ax1.set_title('Word Frequency in Train Data')
ax1.tick_params(axis='x', rotation=45)

# sns.barplot(x='word', y='freq', data=corpus_freq, ax=ax2)
# ax2.set_title('Word Frequency in Train Data')
# ax2.tick_params(axis='x', rotation=45)

# sns.despine(ax=ax1)
# sns.despine(ax=ax2)
plt.show()

# %%
# Cloud for corpus
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(corpus)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# # 4. Splitting

# %%
import pandas as pd 
import numpy as np
df_path = '/content/drive/MyDrive/asetskripsi/filbert12.11.txt'
df = pd.read_csv(df_path, sep='\t', names=['review_text', 'category'])

df.head()
# Out:
#                                          review_text  category
# 0  halo kak  mengasih masuk  timbang atur ukur fo...  positive
# 1  konten download putar   hubungi admin disney  ...  positive
# 2  sorry tanya kualitas video atur mas buram hd  ...  negative
# 3  ganti resolusi layar hitam film mas lanjut  un...  negative
# 4  install aplikasi  rencana menonton series loka...  negative

# %%
# train val split
train_set, val_set = train_test_split(df, test_size=0.2, stratify=df.category, random_state=1)
val_set, test_set = train_test_split(val_set, test_size=0.33, stratify=val_set.category, random_state=1)

# %%
print(f'Train shape: {train_set.shape}')
print(f'Val shape: {val_set.shape}')
print(f'Test shape: {test_set.shape}')
# Out:
# Train shape: (4800, 2)
# Val shape: (804, 2)
# Test shape: (396, 2)

# %%
# export to tsv
train_set.to_csv('train_set.tsv', sep='\t', header=None, index=False)
val_set.to_csv('val_set.tsv', sep='\t', header=None, index=False)
test_set.to_csv('test_set.tsv', sep='\t', header=None, index=False)

# %% [markdown]
# # 5. Modeling

# %% [markdown]
# ## a. Finetuning IndoBERT

# %%
###
# common functions
###
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    
def count_param(module, trainable=False):
    if trainable:
        return sum(p.numel() for p in module.parameters() if p.requires_grad)
    else:
        return sum(p.numel() for p in module.parameters())
    
def get_lr(optimizer):
    for param_group in optimizer.param_groups:
        return param_group['lr']

def metrics_to_string(metric_dict):
    string_list = []
    for key, value in metric_dict.items():
        string_list.append('{}:{:.2f}'.format(key, value))
    return ' '.join(string_list)

# %%
# Set random seed
set_seed(27)

# %% [markdown]
# ## b. Load Model

# %%
# Load Tokenizer and Config
tokenizer = BertTokenizer.from_pretrained('indobenchmark/indobert-base-p2')
config = BertConfig.from_pretrained('indobenchmark/indobert-base-p2')
config.num_labels = DocumentSentimentDataset.NUM_LABELS

# Instantiate model
model = BertForSequenceClassification.from_pretrained('indobenchmark/indobert-base-p1', config=config)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at indobenchmark/indobert-base-p1 and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Struktur model
model
# Out:
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(50000, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %%
count_param(model)
# Out:
# 124443651

# %% [markdown]
# ## c. Prepare Dataset

# %%
train_dataset_path = '/content/train_set.tsv'
valid_dataset_path = '/content/val_set.tsv'
test_dataset_path = '/content/test_set.tsv'

# %%
# fungsi dataset loader dari utils IndoNLU
train_dataset = DocumentSentimentDataset(train_dataset_path, tokenizer, lowercase=True)
valid_dataset = DocumentSentimentDataset(valid_dataset_path, tokenizer, lowercase=True)
test_dataset = DocumentSentimentDataset(test_dataset_path, tokenizer, lowercase=True)

train_loader = DocumentSentimentDataLoader(dataset=train_dataset, max_seq_len=512, batch_size=32, num_workers=16, shuffle=True)  
valid_loader = DocumentSentimentDataLoader(dataset=valid_dataset, max_seq_len=512, batch_size=32, num_workers=16, shuffle=False)  
test_loader = DocumentSentimentDataLoader(dataset=test_dataset, max_seq_len=512, batch_size=32, num_workers=16, shuffle=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
w2i, i2w = DocumentSentimentDataset.LABEL2INDEX, DocumentSentimentDataset.INDEX2LABEL
print(w2i) #word to index
print(i2w) #index to word
# Out:
# {'positive': 0, 'neutral': 1, 'negative': 2}
# {0: 'positive', 1: 'neutral', 2: 'negative'}

# %% [markdown]
# ## d. Uji coba pre-trained model

# %%
text = 'terbaik'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'''Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)
          {logits}''')

# int(torch.argmax(logits))+1
# Out:
# Text: terbaik | Label : positive (40.674%)
#           tensor([[ 0.2750, -0.3823,  0.2134]], grad_fn=<AddmmBackward0>)

# %%
text = 'susah login'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)')
# Out:
# Text: susah login | Label : negative (42.846%)

# %%
text = 'cukup baik'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)')
# Out:
# Text: cukup baik | Label : negative (39.621%)

# %% [markdown]
# ## e. Fine Tuning & Prediksi Evaluation

# %%
# Tentukan optimizer
optimizer = optim.Adam(model.parameters(), lr=3e-6)
model = model.cuda()

# %% [markdown]
# ### Training

# %%
# Train
n_epochs = 10
history = defaultdict(list)
for epoch in range(n_epochs):
    model.train()
    torch.set_grad_enabled(True)
 
    total_train_loss = 0
    list_hyp_train, list_label = [], []

    train_pbar = tqdm(train_loader, leave=True, total=len(train_loader))
    for i, batch_data in enumerate(train_pbar):
        # Forward model
        loss, batch_hyp, batch_label = forward_sequence_classification(model, batch_data[:-1], i2w=i2w, device='cuda')

        # Update model
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tr_loss = loss.item()
        total_train_loss = total_train_loss + tr_loss

        # Hitung skor train metrics
        list_hyp_train += batch_hyp
        list_label += batch_label

        train_pbar.set_description("(Epoch {}) TRAIN LOSS:{:.4f} LR:{:.8f}".format((epoch+1),
            total_train_loss/(i+1), get_lr(optimizer)))

    metrics = document_sentiment_metrics_fn(list_hyp_train, list_label)
    print("(Epoch {}) TRAIN LOSS:{:.4f} {} LR:{:.8f}".format((epoch+1),
        total_train_loss/(i+1), metrics_to_string(metrics), get_lr(optimizer)))
    
    # save train acc for learning curve
    history['train_acc'].append(metrics['ACC'])

    # Evaluate di validation set
    model.eval()
    torch.set_grad_enabled(False)
    
    total_loss, total_correct, total_labels = 0, 0, 0
    list_hyp, list_label = [], []

    pbar = tqdm(valid_loader, leave=True, total=len(valid_loader))
    for i, batch_data in enumerate(pbar):
        batch_seq = batch_data[-1]        
        loss, batch_hyp, batch_label = forward_sequence_classification(model, batch_data[:-1], i2w=i2w, device='cuda')
        
        # Hitung total loss
        valid_loss = loss.item()
        total_loss = total_loss + valid_loss

        # Hitung skor evaluation metrics
        list_hyp += batch_hyp
        list_label += batch_label
        metrics = document_sentiment_metrics_fn(list_hyp, list_label)

        pbar.set_description("VALID LOSS:{:.4f} {}".format(total_loss/(i+1), metrics_to_string(metrics)))
        
    metrics = document_sentiment_metrics_fn(list_hyp, list_label)
    print("(Epoch {}) VALID LOSS:{:.4f} {}".format((epoch+1),
        total_loss/(i+1), metrics_to_string(metrics)))
    
    # save validation acc for learning curve
    history['val_acc'].append(metrics['ACC'])
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 1) TRAIN LOSS:0.8428 LR:0.00000300: 100%|██████████| 150/150 [00:41<00:00,  3.61it/s]
# (Epoch 1) TRAIN LOSS:0.8428 ACC:0.60 F1:0.40 REC:0.41 PRE:0.57 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# VALID LOSS:0.7412 ACC:0.70 F1:0.58 REC:0.55 PRE:0.68: 100%|██████████| 26/26 [00:03<00:00,  7.04it/s]
# (Epoch 1) VALID LOSS:0.7412 ACC:0.70 F1:0.58 REC:0.55 PRE:0.68
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 2) TRAIN LOSS:0.6903 LR:0.00000300: 100%|██████████| 150/150 [00:43<00:00,  3.49it/s]
# (Epoch 2) TRAIN LOSS:0.6903 ACC:0.71 F1:0.61 REC:0.58 PRE:0.68 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.6541 ACC:0.72 F1:0.61 REC:0.58 PRE:0.67: 100%|██████████| 26/26 [00:03<00:00,  6.76it/s]
# (Epoch 2) VALID LOSS:0.6541 ACC:0.72 F1:0.61 REC:0.58 PRE:0.67
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 3) TRAIN LOSS:0.5646 LR:0.00000300: 100%|██████████| 150/150 [00:44<00:00,  3.41it/s]
# (Epoch 3) TRAIN LOSS:0.5646 ACC:0.78 F1:0.68 REC:0.65 PRE:0.76 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# VALID LOSS:0.5870 ACC:0.78 F1:0.66 REC:0.63 PRE:0.79: 100%|██████████| 26/26 [00:03<00:00,  6.68it/s]
# (Epoch 3) VALID LOSS:0.5870 ACC:0.78 F1:0.66 REC:0.63 PRE:0.79
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 4) TRAIN LOSS:0.4725 LR:0.00000300: 100%|██████████| 150/150 [00:44<00:00,  3.35it/s]
# (Epoch 4) TRAIN LOSS:0.4725 ACC:0.82 F1:0.73 REC:0.71 PRE:0.80 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.5403 ACC:0.79 F1:0.69 REC:0.66 PRE:0.79: 100%|██████████| 26/26 [00:03<00:00,  6.60it/s]
# (Epoch 4) VALID LOSS:0.5403 ACC:0.79 F1:0.69 REC:0.66 PRE:0.79
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 5) TRAIN LOSS:0.3833 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.25it/s]
# (Epoch 5) TRAIN LOSS:0.3833 ACC:0.86 F1:0.78 REC:0.75 PRE:0.85 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.5365 ACC:0.81 F1:0.71 REC:0.68 PRE:0.80: 100%|██████████| 26/26 [00:04<00:00,  6.45it/s]
# (Epoch 5) VALID LOSS:0.5365 ACC:0.81 F1:0.71 REC:0.68 PRE:0.80
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 6) TRAIN LOSS:0.3175 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.26it/s]
# (Epoch 6) TRAIN LOSS:0.3175 ACC:0.89 F1:0.82 REC:0.79 PRE:0.88 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.5311 ACC:0.82 F1:0.72 REC:0.69 PRE:0.81: 100%|██████████| 26/26 [00:04<00:00,  6.50it/s]
# (Epoch 6) VALID LOSS:0.5311 ACC:0.82 F1:0.72 REC:0.69 PRE:0.81
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 7) TRAIN LOSS:0.2602 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.23it/s]
# (Epoch 7) TRAIN LOSS:0.2602 ACC:0.91 F1:0.83 REC:0.81 PRE:0.89 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.5366 ACC:0.84 F1:0.75 REC:0.72 PRE:0.81: 100%|██████████| 26/26 [00:04<00:00,  6.43it/s]
# (Epoch 7) VALID LOSS:0.5366 ACC:0.84 F1:0.75 REC:0.72 PRE:0.81
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 8) TRAIN LOSS:0.2048 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.24it/s]
# (Epoch 8) TRAIN LOSS:0.2048 ACC:0.93 F1:0.87 REC:0.84 PRE:0.92 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.5729 ACC:0.83 F1:0.74 REC:0.71 PRE:0.79: 100%|██████████| 26/26 [00:04<00:00,  6.49it/s]
# (Epoch 8) VALID LOSS:0.5729 ACC:0.83 F1:0.74 REC:0.71 PRE:0.79
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 9) TRAIN LOSS:0.1695 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.25it/s]
# (Epoch 9) TRAIN LOSS:0.1695 ACC:0.94 F1:0.89 REC:0.86 PRE:0.92 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.6263 ACC:0.83 F1:0.73 REC:0.70 PRE:0.80: 100%|██████████| 26/26 [00:03<00:00,  6.52it/s]
# (Epoch 9) VALID LOSS:0.6263 ACC:0.83 F1:0.73 REC:0.70 PRE:0.80
#   0%|          | 0/150 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# (Epoch 10) TRAIN LOSS:0.1377 LR:0.00000300: 100%|██████████| 150/150 [00:46<00:00,  3.24it/s]
# (Epoch 10) TRAIN LOSS:0.1377 ACC:0.95 F1:0.91 REC:0.89 PRE:0.94 LR:0.00000300
#   0%|          | 0/26 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# VALID LOSS:0.6587 ACC:0.83 F1:0.74 REC:0.73 PRE:0.76: 100%|██████████| 26/26 [00:03<00:00,  6.52it/s]
# (Epoch 10) VALID LOSS:0.6587 ACC:0.83 F1:0.74 REC:0.73 PRE:0.76

# %% [markdown]
# ### Learning Curve

# %%
plt.plot(history['train_acc'], label='train acc')
plt.plot(history['val_acc'], label='validation acc')
plt.title('Training history')
plt.ylabel('acc')
plt.xlabel('Epoch')
plt.legend()
plt.ylim([0, 1]);

# %%
# Simpan Hasil Prediksi Validation Set
val_df = pd.read_csv(valid_dataset_path, sep='\t', names=['review_text', 'category'])
val_df['pred'] = list_hyp
val_df.head()
val_df.to_csv('val result.csv', index=False)

# %% [markdown]
# ## f. Prediksi Test Set

# %%
# Prediksi test set
model.eval()
torch.set_grad_enabled(False)

total_loss, total_correct, total_labels = 0, 0, 0
pred, list_label = [], []

pbar = tqdm(test_loader, leave=True, total=len(test_loader))
for i, batch_data in enumerate(pbar):
    _, batch_hyp, _ = forward_sequence_classification(model, batch_data[:-1], i2w=i2w, device='cuda')
    pred += batch_hyp
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100%|██████████| 13/13 [00:02<00:00,  5.29it/s]

# %%
# Simpan prediksi test set
test_df = pd.read_csv(test_dataset_path, sep='\t', names=['review_text', 'category'])
test_df['pred'] = pred
test_df.head()
test_df.to_csv('test result.csv', index=False)

# %% [markdown]
# ## e. Test fine-tuned model on sample sentences

# %%
text = 'terbaik'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)')
# Out:
# Text: terbaik | Label : positive (81.605%)

# %%
text = 'susah login'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)')
# Out:
# Text: susah login | Label : negative (99.133%)

# %%
text = 'cukup bagus'
subwords = tokenizer.encode(text)
subwords = torch.LongTensor(subwords).view(1, -1).to(model.device)

logits = model(subwords)[0]
label = torch.topk(logits, k=1, dim=-1)[1].squeeze().item()

print(f'Text: {text} | Label : {i2w[label]} ({F.softmax(logits, dim=-1).squeeze()[label] * 100:.3f}%)')
# Out:
# Text: cukup bagus | Label : negative (98.994%)

# %% [markdown]
# # 6. Evaluasi

# %%
val_real = val_df.category
val_pred = val_df.pred

test_real = test_df.category
test_pred = test_df.pred

# %%
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Greens")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True sentiment')
  plt.xlabel('Predicted sentiment');
  
cm = confusion_matrix(val_real, val_pred)
df_cm = pd.DataFrame(cm, index=['positive', 'neutral', 'negative'], columns=['positive', 'neutral', 'negative'])
show_confusion_matrix(df_cm)

# %%
print(classification_report(val_real, val_pred, target_names=['positive', 'neutral', 'negative']))
# Out:
#               precision    recall  f1-score   support
#
#     positive       0.90      0.87      0.89       458
#      neutral       0.62      0.42      0.50        81
#     negative       0.77      0.89      0.83       265
#
#     accuracy                           0.83       804
#    macro avg       0.76      0.73      0.74       804
# weighted avg       0.83      0.83      0.83       804

# %%
def show_confusion_matrix(confusion_matrix):
  hmap = sns.heatmap(confusion_matrix, annot=True, fmt="d", cmap="Greens")
  hmap.yaxis.set_ticklabels(hmap.yaxis.get_ticklabels(), rotation=0, ha='right')
  hmap.xaxis.set_ticklabels(hmap.xaxis.get_ticklabels(), rotation=30, ha='right')
  plt.ylabel('True sentiment')
  plt.xlabel('Predicted sentiment');
  
cm = confusion_matrix(test_real, test_pred)
df_cm = pd.DataFrame(cm, index=['positive', 'neutral', 'negative'], columns=['positive', 'neutral', 'negative'])
show_confusion_matrix(df_cm)

# %%
print(classification_report(test_real, test_pred, target_names=['positive', 'neutral', 'negative']))
# Out:
#               precision    recall  f1-score   support
#
#     positive       0.91      0.85      0.88       225
#      neutral       0.62      0.50      0.56        40
#     negative       0.75      0.89      0.81       131
#
#     accuracy                           0.83       396
#    macro avg       0.76      0.74      0.75       396
# weighted avg       0.83      0.83      0.82       396
